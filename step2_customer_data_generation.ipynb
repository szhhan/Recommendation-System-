# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Part1: Read processed data

# %%
df_featured = pd.read_csv("data/df_featured.csv",index_col="Name")

# %%
df_featured.head()
# Out:
#             date   open   high    low  close    volume  MACD_12_26  \
# Name
# AAL   2013-02-08  15.07  15.12  14.63  14.75   8407500         NaN
# AAL   2013-02-11  14.89  15.01  14.26  14.46   8882000         NaN
# AAL   2013-02-12  14.45  14.51  14.10  14.27   8126000         NaN
# AAL   2013-02-13  14.30  14.94  14.25  14.66  10259500         NaN
# AAL   2013-02-14  14.94  14.96  13.16  13.99  31879900         NaN
#
#       MACDsign_12_26  MACDdiff_12_26     ROC_5  Momentum_3    MA_5      EMA_3
# Name
# AAL              NaN             NaN       NaN         NaN     NaN        NaN
# AAL              NaN             NaN       NaN         NaN     NaN  14.556667
# AAL              NaN             NaN       NaN         NaN     NaN  14.392857
# AAL              NaN             NaN       NaN       -0.09     NaN  14.535333
# AAL              NaN             NaN -0.051525       -0.47  14.426  14.253871

# %% [markdown]
# # Part 2: Generate fake customer data

# %% [markdown]
# ## 2.1 Generate customer position data

# %%
import random

# %% [markdown]
# #### 2.1.1 Generate fake data: number of stocks that customer is holding

# %%
### randome generate number of stocks that customer is holding
num_holding = random.sample(list(range(3,10)),1)
num_holding
# Out:
# [4]

# %%
### make it into function
def sample(target,num):
    return random.sample(target,num)

# %%
### Generate fake data for 1000 customers
num_customer = 1000
num_stocks = []
for i in range(num_customer):
    num_stocks += sample(list(range(3,10)),1)

# %%
num_stocks[:10]
# Out:
# [8, 7, 8, 7, 5, 3, 5, 5, 3, 6]

# %% [markdown]
# #### 2.1.2 Generate fake data: stocks that customer is holding

# %%
### Extract stock list
stocksList = df_featured.index.unique().values

# %%
stocksList.shape
# Out:
# (505,)

# %%
### sample stocks
stocks = []
for customer,num_stock in zip(range(num_customer),num_stocks):
    sampled_stocks = sample(list(stocksList),num_stock) ### Sample num_stock of stocks from stocks list 
    stocks.append(sampled_stocks)

# %%
stocks
# Out:
# [['MOS', 'MAA', 'AMAT', 'SNA', 'KSU', 'GPN', 'RHI', 'ETR'],
#  ['CNC', 'EQR', 'ADM', 'MMC', 'KHC', 'MAA', 'DHI'],
#  ['GLW', 'PM', 'INTC', 'MAC', 'UA', 'DG', 'AVGO', 'CMI'],
#  ['MLM', 'BLK', 'INTU', 'WDC', 'JBHT', 'MAA', 'BHF'],
#  ['AEE', 'AMGN', 'RE', 'MHK', 'CL'],
#  ['WBA', 'TPR', 'CINF'],
#  ['MAA', 'CB', 'AWK', 'TIF', 'PNC'],
#  ['CSX', 'M', 'FIS', 'ED', 'ATVI'],
#  ['PHM', 'SO', 'DHI'],
#  ['LH', 'XEL', 'TIF', 'NFLX', 'MCD', 'LLY'],
#  ['AMGN', 'CINF', 'CMG', 'MMC', 'MAR', 'UPS', 'FOX', 'PCLN', 'AAP'],
#  ['MO', 'ILMN', 'ZTS', 'MAT', 'SLB', 'MS'],
#  ['COST', 'DRI', 'HES'],
#  ['ZBH', 'FLR', 'AXP'],
#  ['XEL', 'MCK', 'KORS', 'SRE'],
#  ['M', 'ADSK', 'FBHS'],
#  ['TSN', 'PSA', 'EXR'],
#  ['AAPL', 'UA', 'EA', 'HST', 'DIS'],
#  ['MCHP', 'MTB', 'MNST', 'COST'],
#  ['ARE', 'PWR', 'CMG', 'JEC', 'ETFC', 'PM', 'FOX', 'EBAY', 'CB'],
#  ['HIG', 'NWS', 'AMGN', 'LKQ', 'EW', 'NEE', 'CLX'],
#  ['ORLY', 'TWX', 'SRE', 'F', 'V', 'UAA', 'REG'],
#  ['SRCL', 'NRG', 'NSC', 'WM', 'PCG', 'STI'],
#  ['PG', 'AMT', 'AMD', 'VRSK', 'FAST', 'JNPR', 'SYMC'],
#  ['NOC', 'EXPD', 'AFL', 'MU', 'GLW', 'MDT', 'APTV', 'ZION'],
#  ['NKE', 'ROP', 'STT', 'HUM'],
#  ['PG', 'MOS', 'MRO', 'SIG', 'AVGO', 'KORS', 'AGN'],
#  ['MAT', 'STI', 'SYK', 'MDT', 'APC', 'CPB'],
#  ['TSCO', 'IR', 'XEC', 'COF', 'GWW', 'WRK', 'FLR'],
#  ['AEE', 'RCL', 'ACN', 'DE', 'DVN'],
#  ['BRK.B', 'INTU', 'MU', 'PCAR', 'FMC'],
#  ['DLR', 'DUK', 'EMN', 'ANSS', 'CMA'],
#  ['EQT', 'AVGO', 'PBCT', 'GWW', 'ABBV'],
#  ['UA', 'SNPS', 'PSX', 'AES', 'NWSA', 'FB', 'ZBH', 'CMA'],
#  ['NBL', 'WMT', 'PSA', 'AIG', 'HBAN'],
#  ['MS', 'TMK', 'URI', 'CHRW'],
#  ['COF', 'CHK', 'AJG', 'GD', 'ROST', 'CTAS', 'WMT', 'FRT', 'DFS'],
#  ['CVS', 'DAL', 'MCHP', 'QRVO', 'PM', 'MCD', 'AOS', 'GS'],
#  ['HPQ', 'STT', 'CERN', 'NFLX'],
#  ['AWK', 'NUE', 'LEN'],
#  ['ADS', 'BAC', 'NSC', 'JBHT', 'TGT'],
#  ['JCI', 'BA', 'PEG', 'ALGN'],
#  ['PKG', 'TROW', 'UAA', 'HRS', 'SO'],
#  ['BA', 'KMB', 'COST', 'EIX', 'ALK', 'IRM'],
#  ['CHTR', 'K', 'FIS', 'JNPR', 'NLSN', 'AMT'],
#  ['JEC', 'GOOG', 'DVA', 'FOXA', 'CHRW', 'ALL'],
#  ['AJG', 'INCY', 'LNC', 'ETR', 'UAA', 'D', 'RRC', 'DG'],
#  ['MYL', 'LUK', 'URI', 'IP', 'ESRX', 'DRE', 'DRI', 'SNA', 'VRSN'],
#  ['QCOM', 'MO', 'BAC', 'EBAY', 'SNPS', 'MCHP'],
#  ['VRSN', 'UAL', 'PDCO', 'LH', 'AKAM', 'T', 'CBS', 'WHR', 'ADSK'],
#  ['AOS', 'BSX', 'ALK', 'NEM', 'CTAS', 'PYPL'],
#  ['AEE', 'AYI', 'WAT', 'AAPL'],
#  ['CB', 'TWX', 'GPN'],
#  ['AVY', 'GLW', 'AWK'],
#  ['REGN', 'LKQ', 'FRT', 'UPS'],
#  ['PH', 'HAS', 'TMK', 'ADS', 'AGN', 'EXR'],
#  ['NDAQ', 'VAR', 'GPN', 'ZTS', 'BF.B', 'RTN', 'FRT', 'PRU', 'BHF'],
#  ['LH', 'PKG', 'DE', 'KEY', 'NWS'],
#  ['APD', 'SLB', 'JEC', 'TMO', 'CCL', 'LYB', 'TSN'],
#  ['RF', 'JEC', 'T', 'EIX', 'NFLX', 'DXC'],
#  ['XRX', 'NI', 'LEN', 'PFG'],
#  ['CVX', 'SCHW', 'XOM', 'BRK.B'],
#  ['FMC', 'SJM', 'XYL', 'VZ', 'ZION', 'EMN', 'LUV', 'MCHP', 'SYY'],
#  ['MDLZ', 'PFE', 'CBS', 'BAX', 'PDCO', 'EW'],
#  ['DE', 'MDT', 'FCX', 'SWK', 'TSCO', 'CF', 'VZ', 'TWX'],
#  ['SJM', 'AAP', 'MCO', 'KLAC', 'EQR', 'HD', 'ILMN'],
#  ['CHK', 'CSCO', 'HLT'],
#  ['TRIP', 'AET', 'HAL', 'DAL', 'XLNX'],
#  ['SNI', 'VMC', 'ADS'],
#  ['KR', 'APD', 'EMR', 'FRT'],
#  ['MDLZ', 'BSX', 'FRT', 'PXD'],
#  ['WRK', 'DUK', 'TDG', 'CBOE', 'PAYX'],
#  ['CMA', 'FITB', 'TAP', 'ACN'],
#  ['CDNS', 'KLAC', 'VRTX', 'HAS', 'CPB', 'NUE', 'MET'],
#  ['PHM', 'PNR', 'BEN', 'FMC', 'TDG', 'TRV', 'CFG', 'NEM'],
#  ['NUE', 'NVDA', 'APA', 'RRC', 'ANDV', 'GWW', 'IRM'],
#  ['FLIR', 'LNT', 'FL', 'F', 'AXP', 'SHW'],
#  ['CA', 'CFG', 'UA', 'OMC', 'MCK', 'ANDV', 'PNR', 'AME'],
#  ['LEG', 'CAH', 'AET', 'MAC'],
#  ['DLTR', 'PRU', 'PLD', 'ARE', 'DIS', 'NI', 'SLB', 'DG'],
#  ['PLD', 'V', 'IQV'],
#  ['HII', 'HON', 'HD', 'XYL', 'HAL'],
#  ['COP', 'ALXN', 'ROP', 'WFC', 'HD', 'AMP', 'PRU', 'CMI'],
#  ['LLL', 'CMS', 'ZBH'],
#  ['KLAC', 'BBY', 'EXR', 'XOM', 'PLD', 'UTX', 'LEG', 'GM'],
#  ['HSIC', 'AMP', 'AWK', 'FOXA', 'TMO', 'APTV', 'LYB', 'FLIR'],
#  ['FCX', 'RMD', 'ED', 'HUM', 'CMI'],
#  ['WM', 'TAP', 'AFL', 'GM'],
#  ['WU', 'DG', 'BF.B', 'GT', 'PHM', 'TSS', 'BDX', 'FLIR'],
#  ['PSX', 'T', 'ORLY', 'MSFT', 'LKQ', 'CF', 'IBM', 'PEG'],
#  ['SIG', 'TSN', 'BLK', 'ABT', 'KR', 'GOOG', 'DIS', 'EW'],
#  ['SBAC', 'C', 'AEE', 'HBI', 'LKQ', 'BF.B', 'RMD', 'TDG', 'DHI'],
#  ['TEL', 'FRT', 'MDLZ', 'ADSK', 'LNC', 'CHRW', 'BBY', 'ULTA', 'GM'],
#  ['AES', 'MS', 'LNC', 'VNO', 'DWDP', 'ABC', 'PHM', 'GWW'],
#  ['PKI', 'HOG', 'HES', 'CBOE', 'MON', 'BHGE'],
#  ['DPS', 'SBAC', 'PGR'],
#  ['BAC', 'PCAR', 'KMX', 'NLSN', 'DVN', 'HUM', 'FITB', 'LRCX'],
#  ['CAT', 'AGN', 'WMB', 'MNST'],
#  ['KSS', 'VZ', 'ALXN', 'UPS', 'TPR', 'AMGN', 'SWK', 'XRX', 'BF.B'],
#  ['PHM', 'DVN', 'SJM', 'HBI', 'PM'],
#  ['AMZN', 'MNST', 'ATVI', 'K', 'WMT', 'MYL', 'SRE'],
#  ['MU', 'CSCO', 'GPS'],
#  ['RHI', 'LNC', 'MPC', 'SEE', 'TXN', 'MTD'],
#  ['QRVO', 'NBL', 'DUK', 'PX', 'EW', 'WDC', 'LH', 'MLM'],
#  ['EQIX', 'RF', 'APC', 'GOOGL', 'FAST', 'AEE', 'AMG', 'SRE', 'KMX'],
#  ['SBAC', 'KIM', 'COTY', 'ORLY', 'XL', 'WBA', 'BA', 'HCP', 'CFG'],
#  ['PCG', 'FLS', 'BAC', 'FBHS', 'TAP', 'ICE', 'BWA', 'PDCO', 'CNC'],
#  ['CL', 'GIS', 'AAP', 'ED', 'CCL', 'DISCA', 'EOG', 'MSI', 'SYY'],
#  ['AES', 'EXPE', 'AIV', 'LUK'],
#  ['ARE', 'TSN', 'MAS', 'AAPL', 'NSC'],
#  ['AMZN', 'AWK', 'DISCK', 'REG'],
#  ['BHF', 'CNP', 'WEC', 'HAS', 'GOOG', 'SLB'],
#  ['ARE', 'KMB', 'NTRS', 'UPS', 'ALB', 'M', 'AVGO', 'AYI', 'IQV'],
#  ['RSG', 'AET', 'ALL', 'DLTR'],
#  ['LH', 'EW', 'VLO', 'CDNS', 'TDG', 'WMT', 'CMS', 'PG', 'MON'],
#  ['JNPR', 'EMN', 'PKG', 'MAR'],
#  ['COG', 'FBHS', 'CSRA'],
#  ['AMG', 'EQT', 'ED', 'FB'],
#  ['VMC', 'INCY', 'CCL', 'HAL', 'SIG'],
#  ['PNC', 'STZ', 'LEN', 'CTL'],
#  ['GPC', 'ES', 'ULTA', 'ROP', 'NDAQ', 'FE', 'LLY'],
#  ['HP', 'VAR', 'PGR', 'FMC', 'SRCL', 'CTL', 'SLB', 'LNC'],
#  ['CBOE', 'FIS', 'NOV'],
#  ['BLK', 'LNC', 'BRK.B', 'FRT'],
#  ['JNPR', 'PPL', 'BEN', 'TAP', 'ORCL', 'MSFT', 'CCI'],
#  ['CMS', 'AJG', 'DWDP', 'DUK', 'K', 'CCI', 'HST', 'ALK'],
#  ['EIX', 'RHT', 'COF', 'BAX', 'AXP', 'MLM', 'PH'],
#  ['MRO', 'UNH', 'INFO', 'NOV', 'DISCK', 'HUM', 'AYI', 'EL'],
#  ['TRV', 'PX', 'APC', 'AEE', 'FITB', 'JPM', 'IQV', 'EQR', 'ITW'],
#  ['GILD', 'AVB', 'GOOG', 'KIM', 'PEP', 'SNI', 'AMGN', 'MAA'],
#  ['BLL', 'VRSK', 'WYN', 'GPS', 'SNI', 'AME', 'AGN', 'RRC'],
#  ['APD', 'VAR', 'PCLN', 'LNT'],
#  ['HCP', 'ESS', 'BBT', 'PPG', 'NCLH', 'CELG'],
#  ['DPS', 'PKI', 'TRV', 'TSCO'],
#  ['HCP', 'NVDA', 'TJX', 'PLD', 'PGR', 'OMC'],
#  ['LRCX', 'ISRG', 'NKE', 'ECL', 'BLL', 'TWX', 'KMX', 'AMP', 'ANSS'],
#  ['PAYX', 'ALL', 'ZION', 'AET', 'GLW', 'LH', 'XEL', 'ED'],
#  ['FLR', 'FFIV', 'STI', 'MPC', 'CERN', 'BLK'],
#  ['HLT', 'CAT', 'SPG', 'VTR', 'FLR', 'EXPD', 'DHR'],
#  ['AWK', 'HOLX', 'RE'],
#  ['BBY', 'AFL', 'PM', 'SYMC', 'AVB', 'EIX'],
#  ['KSS', 'GOOG', 'LEN', 'KHC', 'GD', 'AMD', 'WBA', 'DXC', 'VRTX'],
#  ['AEE', 'ALXN', 'COO', 'GD', 'ICE', 'FTV', 'BHGE'],
#  ['SYY', 'PRGO', 'VIAB', 'GGP', 'PFE'],
#  ['AMZN', 'HES', 'ROST', 'AEP', 'HCN', 'XL', 'PPG'],
#  ['JNJ', 'SPGI', 'CSRA'],
#  ['RF', 'VIAB', 'CHK', 'MDLZ', 'ICE'],
#  ['XOM', 'JCI', 'IP', 'GM'],
#  ['JNJ', 'NBL', 'DXC', 'NUE', 'AON', 'IPG', 'ECL', 'LNT'],
#  ['AAL', 'ALK', 'SRCL', 'NRG', 'AJG', 'CTXS'],
#  ['KLAC', 'RSG', 'CVX', 'SRCL', 'ALGN', 'WYNN'],
#  ['WMB', 'LNT', 'INTU'],
#  ['AJG', 'NDAQ', 'LB', 'VRTX', 'ADP', 'BAC', 'EVHC', 'SBUX'],
#  ['WY', 'MA', 'LEN', 'ALGN', 'WDC', 'BRK.B', 'CA', 'NTRS', 'EL'],
#  ['ABBV', 'NOC', 'MCHP', 'TRIP', 'HON', 'TAP'],
#  ['SO', 'KR', 'CSX', 'ITW', 'WRK', 'WEC'],
#  ['TRIP', 'ABBV', 'C', 'PHM', 'NKE', 'GGP', 'WAT', 'A'],
#  ['BF.B', 'TDG', 'AME', 'GOOG', 'HST'],
#  ['FITB', 'IDXX', 'NEE', 'MCHP', 'AES', 'WM', 'CHTR', 'CSX', 'JEC'],
#  ['CINF', 'CAG', 'ADM', 'NWSA', 'FCX', 'UNH'],
#  ['ADS', 'CINF', 'LEN'],
#  ['NBL', 'TSCO', 'LUK', 'CFG', 'WMT', 'KMX'],
#  ['RF', 'ANSS', 'COL', 'CBOE', 'PCAR', 'ETFC'],
#  ['GT', 'DUK', 'REG', 'GE', 'SLB', 'AET', 'DGX', 'PRGO', 'OKE'],
#  ['NEE', 'CAG', 'UAA', 'CA', 'PCLN'],
#  ['ORCL', 'AJG', 'GGP', 'STI', 'REGN', 'CTAS', 'RCL', 'AKAM'],
#  ['EXR', 'ZBH', 'AMP', 'PLD', 'CELG', 'TGT', 'MCO'],
#  ['COST', 'APD', 'SBUX'],
#  ['MAC', 'MTD', 'ORCL', 'EQIX', 'DWDP', 'MCD', 'ATVI', 'BIIB'],
#  ['UA', 'HOLX', 'SPG', 'DIS', 'ALLE', 'TSN', 'BAX', 'AME', 'BEN'],
#  ['VRTX', 'IRM', 'SHW', 'KMI', 'GT', 'COO', 'EQIX'],
#  ['APC', 'HAS', 'GOOG', 'MAT', 'APD', 'TRV'],
#  ['PPL', 'HPE', 'GOOGL'],
#  ['TSS', 'WMT', 'AOS', 'IVZ', 'CBOE', 'GPC', 'ALL', 'ATVI'],
#  ['LEG', 'CMG', 'BIIB', 'JBHT', 'FCX', 'DUK', 'OXY', 'LUK'],
#  ['EMN', 'K', 'BHGE', 'SIG', 'FE', 'CB', 'ARNC', 'PM', 'FITB'],
#  ['RCL', 'ADS', 'PHM', 'LNT'],
#  ['AVGO', 'MON', 'COST', 'SRE', 'NWL', 'PEP', 'ZION', 'AVY'],
#  ['BLK', 'DRI', 'RSG', 'TXT', 'ROK', 'SLG', 'EOG'],
#  ['BSX', 'AES', 'EOG', 'IRM', 'CI', 'URI'],
#  ['IFF', 'DLTR', 'AES'],
#  ['AET', 'ADSK', 'MAS', 'VIAB'],
#  ['FMC', 'LB', 'CCL', 'EL', 'KSS'],
#  ['ALXN', 'ETFC', 'PEP', 'CAH', 'DAL', 'EXR', 'SPGI', 'CNC'],
#  ['HRB', 'FLS', 'DVN', 'ABBV'],
#  ['VZ', 'MMC', 'RHI', 'WEC'],
#  ['EFX', 'BEN', 'KEY'],
#  ['XEC', 'PWR', 'TWX', 'AAL', 'BIIB'],
#  ['HSY', 'PHM', 'A', 'SRCL', 'FRT', 'OXY', 'CBS', 'NOV'],
#  ['ES', 'WEC', 'JBHT'],
#  ['CSCO', 'VNO', 'VIAB', 'WM', 'EQR'],
#  ['PSX', 'SPGI', 'DXC', 'SRE', 'MMC'],
#  ['XEC', 'APA', 'CFG', 'DFS', 'BBT', 'CAH', 'RSG'],
#  ['RHI', 'IR', 'AAL', 'CMCSA', 'MMC'],
#  ['ROP', 'TXN', 'PNW', 'MAR', 'SBUX'],
#  ['CLX', 'SJM', 'ILMN', 'JBHT', 'HUM', 'JPM', 'FTI', 'ADP', 'MCO'],
#  ['GM', 'PFG', 'PNC', 'DVN', 'PLD'],
#  ['BK', 'LEG', 'CI', 'AMG', 'AIZ', 'AMD'],
#  ['LRCX', 'LUK', 'PPG', 'HCN', 'IPG', 'PXD', 'DGX'],
#  ['KIM', 'EA', 'CSCO', 'COP', 'XRAY'],
#  ['SPGI', 'PWR', 'AES', 'PPL', 'VZ', 'RRC'],
#  ['DHR', 'FLR', 'ANSS', 'WM', 'MYL', 'CTXS', 'WMB', 'MDT', 'MCHP'],
#  ['BHF', 'AKAM', 'ADI'],
#  ['XEC', 'EOG', 'FLS', 'HOG', 'MLM', 'BIIB', 'AVB', 'KEY'],
#  ['EXPE', 'MMC', 'MTD'],
#  ['IT', 'BXP', 'HD', 'WBA', 'HPQ', 'KO', 'PVH', 'CAG'],
#  ['LYB', 'UNM', 'ROP'],
#  ['SRE', 'NDAQ', 'KHC', 'ICE', 'PBCT', 'TJX', 'MCO'],
#  ['ORCL', 'MU', 'DTE', 'EXPD', 'EFX', 'PCG'],
#  ['COP', 'ROP', 'HPE'],
#  ['CNP', 'TROW', 'A', 'TXN', 'UAL', 'DRI', 'NAVI', 'MCD', 'STZ'],
#  ['IDXX', 'HAS', 'HPQ', 'AET', 'RCL', 'INCY', 'AOS'],
#  ['XRAY', 'AMGN', 'HCA'],
#  ['INTU', 'IPG', 'FITB', 'ORCL', 'SO', 'DAL'],
#  ['DRE', 'HPE', 'MAC'],
#  ['KMI', 'CI', 'ARE', 'MS', 'NFX', 'ALGN'],
#  ['PEG', 'PFG', 'BAC', 'ORLY', 'PKG', 'CMA', 'GM'],
#  ['MYL', 'SPG', 'AIG', 'NOC'],
#  ['PRGO', 'MNST', 'KR', 'CHK', 'LEG', 'CB', 'IP', 'CRM', 'VAR'],
#  ['GILD', 'CLX', 'FTV', 'MNST', 'CAT'],
#  ['ALGN', 'COF', 'CNC', 'DISCA', 'NUE'],
#  ['RMD', 'IR', 'PPL', 'GE'],
#  ['GPN', 'HAS', 'ISRG'],
#  ['VIAB', 'AVY', 'LRCX', 'FOX', 'HCP'],
#  ['AAPL', 'AOS', 'NRG', 'AON', 'GRMN'],
#  ['AZO', 'PCG', 'ISRG', 'JNJ', 'IRM', 'CHTR'],
#  ['XRAY', 'ALLE', 'COO', 'CHRW', 'ALK', 'WU'],
#  ['SPG', 'ARE', 'PHM', 'MAR'],
#  ['HBI', 'PBCT', 'EXC', 'STZ', 'HLT', 'ADM'],
#  ['JEC', 'BBY', 'IVZ', 'KSU'],
#  ['ESRX', 'TEL', 'SEE', 'VRSK', 'MAC'],
#  ['BMY', 'MON', 'RSG', 'UAA', 'URI', 'MCO', 'MTD', 'CHTR'],
#  ['PBCT', 'ADS', 'ESRX', 'OXY', 'JNPR', 'IBM'],
#  ['ADBE', 'TAP', 'BEN', 'IVZ', 'PLD', 'ALK', 'DWDP', 'AEE', 'SRE'],
#  ['PEP', 'AIG', 'ROP', 'BSX', 'SPGI', 'GD', 'KEY', 'MYL'],
#  ['QRVO', 'KIM', 'JBHT', 'CBS', 'FAST', 'OXY', 'M', 'MAT', 'VLO'],
#  ['SYF', 'APA', 'VTR', 'PSX', 'AMGN', 'AEP', 'LB', 'COG'],
#  ['HLT', 'SO', 'NWS', 'JCI', 'LRCX', 'TGT', 'NI'],
#  ['SYY', 'DHI', 'AXP', 'AZO', 'JEC', 'VRSK'],
#  ['PBCT', 'RF', 'UNH', 'IQV', 'NOV', 'WLTW', 'MTB', 'BHGE', 'KMI'],
#  ['T', 'CMI', 'WFC', 'TDG', 'WLTW'],
#  ['CHTR', 'NOV', 'KSU', 'ALK', 'CMCSA', 'AMGN'],
#  ['LYB', 'WY', 'COP', 'IP'],
#  ['VNO', 'PDCO', 'JNPR', 'NTRS', 'CB', 'ALXN', 'HCN', 'COTY', 'PRGO'],
#  ['INFO', 'ECL', 'IDXX', 'WDC'],
#  ['BBY', 'NOV', 'KMB', 'AES', 'RE', 'FFIV', 'AON', 'HD', 'JWN'],
#  ['BK', 'GLW', 'JWN'],
#  ['AMAT', 'CMS', 'UTX', 'QRVO', 'MAC', 'PWR', 'C', 'T', 'ESS'],
#  ['CAH', 'SNI', 'ALGN', 'PCLN', 'RE', 'FRT', 'SYMC', 'K'],
#  ['WMB', 'VRSK', 'TDG', 'EXPD', 'SNI', 'SJM', 'FBHS'],
#  ['AEE', 'ALK', 'PSX', 'TJX', 'AMD'],
#  ['BA', 'SLB', 'ADSK', 'SYY'],
#  ['QRVO', 'SCG', 'BA', 'SLG', 'CNC', 'CCI', 'EFX'],
#  ['IT', 'ESRX', 'PKG', 'EW', 'TXN'],
#  ['ETFC', 'REG', 'DE', 'VRTX', 'PDCO'],
#  ['TSCO', 'JPM', 'PEP'],
#  ['CB', 'GE', 'UA', 'V', 'AGN', 'WRK', 'NDAQ', 'ETN'],
#  ['NEM', 'JBHT', 'AIV'],
#  ['PG', 'ADSK', 'GD'],
#  ['CLX', 'CAH', 'AEE', 'O', 'HST', 'UHS'],
#  ['AIZ', 'CHD', 'STI', 'HSIC', 'SJM', 'REG'],
#  ['VRSK', 'SEE', 'APA', 'UPS', 'XOM', 'NFLX'],
#  ['EQIX', 'COST', 'PKI', 'AWK', 'MSFT', 'EW', 'GGP', 'MOS', 'PCLN'],
#  ['LEG', 'CCI', 'HSIC', 'SCG', 'MPC', 'HOLX'],
#  ['FRT', 'NSC', 'CRM', 'LB', 'HCP'],
#  ['NUE', 'COST', 'HD', 'RMD', 'DVA'],
#  ['XLNX', 'PBCT', 'PXD'],
#  ['FOXA', 'APH', 'ADM'],
#  ['HBI', 'ESS', 'CAH', 'AOS', 'MMM', 'VTR', 'RTN'],
#  ['EQR', 'ARE', 'DGX', 'UNP'],
#  ['DAL', 'MCK', 'UAL', 'AMAT', 'CCI', 'COP', 'IQV', 'ANSS', 'MDT'],
#  ['PRU', 'MDLZ', 'NTRS', 'KSU', 'ANTM', 'STI', 'CDNS', 'ESS', 'VFC'],
#  ['COL', 'MYL', 'LNT', 'TMK', 'DGX', 'DPS'],
#  ['MMC', 'HBAN', 'KORS', 'CME', 'ANSS'],
#  ['K', 'TXT', 'COST', 'CDNS', 'FITB', 'D', 'ETN'],
#  ['RL', 'MRK', 'BBY', 'RCL', 'M', 'ROP', 'AEE'],
#  ['MAS', 'HST', 'GPN', 'LYB', 'BEN'],
#  ['ATVI', 'PSA', 'CVX', 'LMT'],
#  ['CTL', 'AGN', 'AMT', 'MSFT', 'ULTA', 'NEE', 'CME'],
#  ['SNPS', 'UDR', 'UNP', 'NOV', 'EXR', 'BAC', 'HCA', 'SYMC', 'DISCK'],
#  ['KSU', 'ROP', 'MCK', 'SNPS', 'MCD'],
#  ['MCK', 'AMD', 'SWK'],
#  ['IRM', 'MAR', 'ADM', 'SWK'],
#  ['DTE', 'HP', 'MAR', 'MRK', 'GPS', 'GPN'],
#  ['PCLN', 'UNH', 'CRM'],
#  ['SLB', 'MGM', 'KIM', 'MOS', 'DIS', 'LKQ', 'TRV', 'NRG', 'GPS'],
#  ['ALLE', 'AOS', 'FDX', 'QCOM', 'IP', 'WHR'],
#  ['WLTW', 'FLIR', 'ADBE', 'PCAR', 'FTV', 'HSIC', 'HCA', 'GGP', 'JNJ'],
#  ['TJX', 'MTD', 'ALL', 'COF', 'HOLX'],
#  ['TIF', 'BLK', 'AMD'],
#  ['MO', 'ADI', 'STT', 'AXP', 'WAT', 'ECL'],
#  ['FL', 'ILMN', 'CMI'],
#  ['AXP', 'EQR', 'XEC', 'HIG'],
#  ['SWK', 'ETFC', 'CMCSA'],
#  ['UNM', 'LOW', 'FIS', 'WDC', 'PCG', 'KLAC'],
#  ['CLX', 'MET', 'HON', 'CNC'],
#  ['DHI', 'CSCO', 'DXC'],
#  ['AIG', 'MO', 'SCHW', 'SWKS', 'BEN', 'AMD'],
#  ['ALGN', 'FL', 'AMAT', 'IR', 'COTY', 'CMG', 'MSFT', 'VAR', 'PNW'],
#  ['AEP', 'SWK', 'CMA', 'WY', 'ETN'],
#  ['XRX', 'ARNC', 'SYK', 'ROP', 'CELG', 'DXC', 'FBHS', 'HPE'],
#  ['GE', 'NKE', 'CTSH', 'RF'],
#  ['MAA', 'CBS', 'DXC', 'EFX', 'SYK'],
#  ['DRI', 'SNPS', 'UAA', 'RRC', 'MOS', 'SWK', 'CMI'],
#  ['C', 'DHR', 'WYN', 'IPG', 'CVX', 'PM'],
#  ['LKQ', 'ZTS', 'RMD', 'CCI', 'NAVI', 'AOS'],
#  ['HES', 'GRMN', 'AMZN', 'ADP', 'MLM', 'NKE', 'BAC'],
#  ['IBM', 'WM', 'JWN', 'NLSN', 'VIAB', 'WYNN', 'ESRX', 'EMN'],
#  ['SLB', 'LOW', 'KSU', 'SNPS', 'PLD', 'SYF'],
#  ['DTE', 'AMAT', 'CBS', 'WEC', 'DFS', 'GS', 'JNJ', 'NWS'],
#  ['FLR', 'CAT', 'PKI'],
#  ['CSX', 'IR', 'PSX', 'AXP', 'GLW', 'PYPL', 'CAH'],
#  ['HIG', 'WHR', 'COF', 'UNM', 'CRM', 'HLT', 'MHK', 'K'],
#  ['DOV', 'KSS', 'CI', 'SO', 'HPE', 'GIS', 'NI', 'ADBE'],
#  ['PXD', 'COO', 'HLT', 'AFL'],
#  ['SPG', 'ACN', 'TRIP', 'SWK', 'D'],
#  ['IVZ', 'AFL', 'SO', 'ABBV'],
#  ['SNA', 'VZ', 'ACN', 'CMG', 'MAS', 'AOS', 'EVHC'],
#  ['LMT', 'FLR', 'NLSN'],
#  ['MAC', 'BRK.B', 'DPS', 'FL', 'SYF', 'CNC', 'LUV', 'ALXN', 'GPS'],
#  ['AEP', 'KMB', 'XRAY'],
#  ['SWK', 'AMT', 'PXD', 'ALLE', 'STX', 'TSS', 'ROK'],
#  ['PM', 'DISH', 'RTN'],
#  ['ADM', 'IVZ', 'NTAP'],
#  ['GWW', 'NFLX', 'MMC', 'GRMN', 'HBI', 'CAG'],
#  ['VRSN', 'NKE', 'ROK', 'RHI'],
#  ['EW', 'LYB', 'SYY'],
#  ['LOW', 'MET', 'DWDP', 'VZ', 'UA', 'IBM', 'ADI', 'NAVI', 'COF'],
#  ['XL', 'BK', 'HOLX', 'KIM', 'DHR', 'CPB', 'NEM'],
#  ['STI', 'AMT', 'ROST', 'VAR', 'RL', 'AES', 'MMM', 'STZ', 'JCI'],
#  ['CMA', 'TRIP', 'RHI', 'ORCL', 'MYL'],
#  ['EBAY', 'ALGN', 'LNC', 'MAA', 'NSC', 'DIS', 'PHM', 'WEC', 'AVGO'],
#  ['ADBE', 'OXY', 'AKAM', 'AOS', 'APC', 'WAT', 'CSRA', 'TAP'],
#  ['DUK', 'HUM', 'SYK', 'SYF', 'DWDP', 'EXPE'],
#  ['GRMN', 'SPG', 'TDG', 'KSU'],
#  ['SRCL', 'RF', 'APA', 'MCHP'],
#  ['KMX', 'AON', 'XLNX', 'USB', 'EA', 'DGX'],
#  ['HII', 'MYL', 'PVH'],
#  ['CHK', 'CSCO', 'CVS', 'LUK', 'DHR', 'ARNC', 'HP', 'HBI', 'FDX'],
#  ['CAH', 'HRL', 'KO', 'BHF', 'UDR', 'HII', 'TMK'],
#  ['PBCT', 'LYB', 'EBAY', 'PSA', 'STZ', 'FRT', 'NRG'],
#  ['ADM', 'LH', 'CSRA', 'AFL', 'AMZN', 'HRB'],
#  ['GD', 'FTI', 'MCK', 'RTN'],
#  ['LRCX', 'BLL', 'AFL', 'CVX', 'LUK', 'BWA'],
#  ['ABC', 'SJM', 'FCX', 'ECL', 'LEN'],
#  ['APD', 'T', 'IVZ', 'EMR', 'EIX', 'PFE'],
#  ['NI', 'EMN', 'FE', 'RJF', 'RTN'],
#  ['SWKS', 'CLX', 'AEE'],
#  ['DRI', 'CAG', 'GT', 'DUK', 'ED', 'TROW', 'CELG', 'AMT', 'ETN'],
#  ['VRTX', 'NUE', 'BBT', 'SPGI'],
#  ['FIS', 'NWL', 'AWK', 'FB', 'CLX', 'PFG'],
#  ['JCI', 'PNR', 'SRE', 'KSU', 'CELG', 'IFF', 'DFS', 'LLL', 'FLR'],
#  ['AAL', 'AES', 'FMC'],
#  ['JNPR', 'REG', 'SO', 'PCG', 'HBI', 'XYL', 'DVN'],
#  ['MET', 'CHK', 'DUK', 'PXD', 'PPL', 'F', 'XEC', 'NBL', 'REGN'],
#  ['CSRA', 'TXT', 'ITW', 'IRM', 'FTV', 'HAS', 'JNPR', 'BLK'],
#  ['UAA', 'CERN', 'CAG', 'WBA'],
#  ['NSC', 'AVB', 'MON', 'ETR'],
#  ['MSFT', 'JNJ', 'WHR', 'SCHW', 'BAX', 'DHR'],
#  ['AME', 'BMY', 'AEP', 'RRC', 'TRV', 'MSFT', 'EBAY', 'DAL'],
#  ['RF', 'TDG', 'SIG', 'GPS', 'WDC', 'V', 'PNW'],
#  ['STI', 'FBHS', 'HSIC', 'GM', 'FTV', 'CSRA', 'CLX'],
#  ['TXN', 'MAC', 'ALB', 'DVN', 'UAL', 'CAG', 'ADBE', 'PCAR'],
#  ['ANSS', 'NRG', 'WLTW', 'BF.B', 'MON'],
#  ['HOG', 'HII', 'WBA', 'SBAC', 'RRC', 'PKI', 'MHK', 'MSFT', 'EXPE'],
#  ['HLT', 'MET', 'CINF', 'AWK', 'WMT', 'RSG'],
#  ['ED', 'CSX', 'DISCA', 'CNP', 'ATVI', 'UNP', 'LLY', 'USB', 'SRCL'],
#  ['JPM', 'PKG', 'VFC', 'PCG', 'SBUX', 'DISCK', 'MHK', 'ABC', 'NAVI'],
#  ['MAR', 'KHC', 'CTL', 'ANSS', 'HES', 'OMC', 'FL', 'ABC', 'CTAS'],
#  ['AAL', 'CNC', 'BBT', 'ARNC'],
#  ['KORS', 'ETR', 'MRK', 'HIG', 'MA', 'PNW'],
#  ['APH', 'WY', 'AGN', 'AMP', 'MON'],
#  ['IPG', 'RF', 'IRM', 'CMA', 'BHGE'],
#  ['C', 'NEM', 'URI'],
#  ['CVX', 'CBG', 'CDNS', 'MTD', 'RRC', 'EA', 'GPN'],
#  ['SRE', 'JNJ', 'AAPL', 'APD', 'EIX'],
#  ['HPQ', 'PX', 'JBHT', 'MNST'],
#  ['UPS', 'ALLE', 'DIS', 'CHK', 'CXO', 'AIZ', 'AMP', 'DVA'],
#  ['FFIV', 'LNT', 'PHM', 'DVA', 'TROW'],
#  ['NEM', 'ICE', 'MSFT', 'ACN', 'STZ', 'STT'],
#  ['LB', 'IFF', 'VAR', 'ROP', 'AMZN'],
#  ['ISRG', 'DGX', 'DLTR', 'RRC', 'APTV', 'TIF', 'ED', 'PKI'],
#  ['CAT', 'TSCO', 'MMC', 'C', 'STX', 'TMK'],
#  ['MCO', 'WLTW', 'CMI', 'KEY', 'ULTA', 'TPR', 'SYK'],
#  ['AVGO', 'EVHC', 'HD', 'AMT', 'DOV', 'YUM', 'EL'],
#  ['AME', 'CXO', 'ACN', 'UNH', 'ETN', 'LNC', 'AVGO'],
#  ['LEG', 'BBT', 'LRCX', 'CF', 'SNA', 'COO', 'WMB', 'XEC'],
#  ['LH', 'HCN', 'AME', 'UTX', 'D', 'WM', 'LUK', 'TDG', 'PNW'],
#  ['MON', 'CCI', 'PCAR'],
#  ['GOOGL', 'DISCK', 'BEN'],
#  ['PNC', 'AVY', 'MKC', 'DLR', 'SPGI', 'PH', 'BWA', 'SRCL', 'CPB'],
#  ['EIX', 'ZBH', 'RRC', 'RTN', 'MON'],
#  ['SRE', 'AEE', 'C', 'PLD', 'HAL', 'ADS', 'PEG'],
#  ['ROP', 'IVZ', 'EXR'],
#  ['CBS', 'COL', 'URI', 'PGR'],
#  ['CBG', 'HAS', 'ESRX'],
#  ['CSCO', 'KORS', 'ALXN', 'RSG', 'FCX', 'PKI', 'GT', 'INFO', 'VFC'],
#  ['AVB', 'ETFC', 'ACN', 'GILD', 'NSC', 'AWK'],
#  ['EL', 'NLSN', 'LKQ', 'KORS'],
#  ['KMB', 'USB', 'ISRG', 'EOG', 'BDX'],
#  ['AAPL', 'PGR', 'FDX', 'SEE', 'PNW', 'WEC', 'AME', 'SPG', 'SNA'],
#  ['WU', 'UHS', 'AMZN', 'XL', 'LUV', 'MAS', 'PG'],
#  ['NVDA', 'IDXX', 'ABBV', 'WYN', 'LYB', 'AVB'],
#  ['PDCO', 'PEG', 'CF', 'AMT', 'HES', 'ROK', 'EXPE', 'M', 'EA'],
#  ['EOG', 'F', 'D'],
#  ['CAH', 'MMC', 'NDAQ', 'GIS', 'HIG', 'IRM', 'JBHT'],
#  ['COG', 'BIIB', 'IP', 'BHF', 'PCLN', 'XEC', 'HES'],
#  ['NEE', 'NTRS', 'WFC', 'ADSK', 'NVDA', 'DPS'],
#  ['RF', 'FTI', 'AON', 'NAVI', 'V', 'EQT', 'PG'],
#  ['ABT', 'EW', 'SO', 'COO', 'ALK', 'DXC', 'AAP'],
#  ['CINF', 'GD', 'LUV', 'SO', 'AAPL', 'HAS', 'EIX', 'TXT'],
#  ['NLSN', 'CMI', 'HRL', 'AEE', 'KHC', 'KSU', 'TGT', 'NWSA', 'CMG'],
#  ['KSS', 'PFG', 'MRK'],
#  ['KSU', 'NI', 'TXT', 'MDLZ'],
#  ['PNR', 'CFG', 'PSX', 'CLX', 'SHW', 'EA', 'AAP', 'KSU'],
#  ['VTR', 'LMT', 'BBT', 'ABBV', 'PDCO', 'ADSK', 'KHC', 'F', 'AKAM'],
#  ['TAP', 'APTV', 'CNP', 'EMN', 'NLSN', 'EXPE', 'MCD', 'HUM', 'DAL'],
#  ['DPS', 'AMT', 'AEP', 'DFS', 'ZTS'],
#  ['AIG', 'MCD', 'FB', 'PFE', 'CMA', 'EFX', 'VIAB'],
#  ['JCI', 'NCLH', 'STT', 'BHF', 'BMY', 'EXPD', 'LLY', 'ALL'],
#  ['UTX', 'CLX', 'EXR', 'CFG', 'NEE', 'VAR', 'JNJ'],
#  ['PG', 'EXPE', 'CHTR', 'COST', 'IP'],
#  ['INTU', 'NAVI', 'PPL', 'BF.B', 'SNI', 'NTAP', 'EBAY', 'PCAR'],
#  ['GOOGL', 'PFG', 'UNM', 'HUM', 'CMA', 'DLR', 'KO'],
#  ['JNJ', 'HPE', 'AMP', 'AAL', 'PCLN', 'MTD', 'ROP'],
#  ['SCG', 'PEG', 'PRU', 'DWDP', 'MAT', 'CB', 'IP'],
#  ['IDXX', 'ARNC', 'STT', 'RRC', 'ROP', 'ETFC', 'CME', 'BHGE', 'CFG'],
#  ['FRT', 'HCN', 'TIF', 'DGX', 'DUK', 'PG', 'AEP', 'KORS'],
#  ['NBL', 'NRG', 'ADBE', 'SLB', 'DWDP', 'DE', 'APC'],
#  ['DE', 'MOS', 'AIV', 'SYF', 'UPS', 'PDCO', 'BF.B', 'NAVI', 'MSI'],
#  ['BWA', 'MO', 'DHR', 'CLX'],
#  ['IBM', 'ABC', 'NRG', 'WM', 'NKE', 'GPC', 'BLK', 'FTV'],
#  ['FITB', 'TEL', 'MS', 'ADSK', 'TPR', 'O', 'MLM'],
#  ['XEL', 'BRK.B', 'DIS'],
#  ['XRAY', 'TXT', 'RHT', 'DVN', 'DG', 'CBS', 'FTI'],
#  ['GWW', 'DWDP', 'EMN', 'IP', 'SYK', 'FAST', 'FOX', 'AME'],
#  ['DHI', 'TMO', 'RJF', 'LLY', 'ZBH', 'ATVI', 'KEY', 'IT'],
#  ['EIX', 'DHR', 'AES', 'RJF'],
#  ['C', 'MET', 'MTB'],
#  ['PNC', 'BSX', 'FMC'],
#  ['IVZ', 'NAVI', 'KR', 'FCX', 'NWSA'],
#  ['SYF', 'MO', 'VIAB', 'PNR', 'TIF', 'KLAC', 'AVY', 'GD'],
#  ['HAS', 'WMB', 'KSU', 'IVZ', 'PWR'],
#  ['SYMC', 'BDX', 'FMC', 'MDLZ', 'OXY'],
#  ['ALK', 'CFG', 'WYN', 'MRO', 'MKC', 'HSIC', 'VIAB', 'COL'],
#  ['FOXA', 'RF', 'PKI', 'HCN'],
#  ['AGN', 'SPG', 'VIAB', 'KR', 'FOXA', 'CNP', 'FTV', 'WFC', 'UA'],
#  ['PXD', 'PNC', 'EW', 'BXP', 'NTAP', 'MSI', 'WHR'],
#  ['RMD', 'BHF', 'RSG', 'CI', 'FOX'],
#  ['CRM', 'LLL', 'TMK', 'BLL', 'FDX', 'IP', 'VFC'],
#  ['LLY', 'EVHC', 'REGN', 'GM', 'SRCL'],
#  ['EOG', 'IRM', 'XEC', 'AOS'],
#  ['EXC', 'PH', 'KR', 'SEE', 'ADM', 'AZO', 'UDR'],
#  ['MS', 'AMAT', 'BWA', 'WEC', 'DVA', 'CBS', 'BA'],
#  ['MCO', 'JWN', 'WBA', 'HPQ', 'GRMN', 'PXD', 'CMA', 'KMB'],
#  ['EXPD', 'DVA', 'FTI', 'NVDA'],
#  ['LB', 'WMT', 'ETFC', 'RHI', 'ULTA', 'NEE', 'EL'],
#  ['CVX', 'ANSS', 'SBAC', 'MET', 'COTY', 'WMB', 'MLM', 'COL'],
#  ['UNM', 'ETN', 'PG', 'COL', 'GE', 'NEE'],
#  ['NFX', 'XYL', 'AET', 'PDCO', 'ICE', 'WLTW'],
#  ['MPC', 'VRTX', 'UNP', 'GLW', 'OMC', 'APD', 'VNO', 'ARE'],
#  ['LUV', 'NEE', 'MAA', 'BDX', 'TGT', 'KO', 'DHR', 'CMG'],
#  ['PXD', 'STI', 'VRSN'],
#  ['WAT', 'JEC', 'NTAP', 'DISH', 'CBS', 'BIIB', 'CME', 'AZO'],
#  ['KSU', 'PRGO', 'ETFC', 'DRI'],
#  ['NVDA', 'NSC', 'T', 'PGR', 'ZBH', 'CBS', 'KHC', 'FOX'],
#  ['FLS', 'EQT', 'SHW', 'CTSH', 'PWR', 'QCOM', 'LNT', 'FFIV', 'AMT'],
#  ['NFX', 'GS', 'NFLX'],
#  ['WY', 'BHF', 'M', 'FRT', 'XOM', 'MAA', 'MA', 'ZTS', 'DOV'],
#  ['VNO', 'JBHT', 'CI', 'APTV', 'DIS'],
#  ['CCI', 'GILD', 'SIG', 'TIF', 'TAP', 'PDCO', 'CNC', 'AMD', 'CTL'],
#  ['ROP', 'CCL', 'ANTM', 'XLNX', 'LUK', 'CHRW'],
#  ['PKI', 'AVGO', 'NAVI'],
#  ['AZO', 'TGT', 'MS', 'BSX', 'JBHT', 'C'],
#  ['COST', 'XEC', 'MSFT', 'EQIX', 'NSC', 'INFO', 'CTXS'],
#  ['TDG', 'KSS', 'NCLH', 'ETFC'],
#  ['KMI', 'PNW', 'XL'],
#  ['ADBE', 'MAT', 'ESS', 'FFIV', 'LMT'],
#  ['AME', 'DRE', 'ALL', 'EMN', 'CERN'],
#  ['MCO', 'ESRX', 'EXC', 'MAT', 'ETN', 'A', 'SLG', 'SWK', 'NUE'],
#  ['WAT', 'KMB', 'SBUX'],
#  ['BAX', 'HBI', 'MAR', 'EIX', 'CAT'],
#  ['SEE', 'REGN', 'RSG', 'MSFT'],
#  ['GLW', 'NEM', 'AGN', 'WY', 'PNR'],
#  ['APC', 'STZ', 'FISV', 'ABT', 'DVN', 'FMC', 'LLY', 'CCL', 'MAS'],
#  ['WMT', 'ALLE', 'QRVO', 'MLM', 'PRU', 'WU', 'ALB', 'ABBV', 'FDX'],
#  ['CA', 'PGR', 'T'],
#  ['BAC', 'CHD', 'TAP', 'CHK', 'ADM'],
#  ['APH', 'IBM', 'ADI', 'QRVO', 'AVY', 'NBL'],
#  ['PX', 'NWL', 'SYMC'],
#  ['CVS', 'PEG', 'LOW', 'MYL', 'IT', 'RF', 'SNI'],
#  ['HRB', 'ZBH', 'CHK', 'ES', 'STI', 'AKAM', 'ISRG'],
#  ['PYPL', 'YUM', 'COST', 'HIG', 'GPS', 'SHW'],
#  ['CLX', 'BLK', 'CA'],
#  ['CHD', 'BDX', 'GPC', 'INCY', 'ADS', 'XRX', 'MO', 'RMD'],
#  ['AMP', 'FCX', 'WM', 'FMC', 'YUM', 'CAG', 'PKI', 'AMT', 'AEP'],
#  ['FL', 'CERN', 'NOC', 'NKE', 'HIG', 'SJM', 'APA'],
#  ['CL', 'EW', 'VLO', 'WY', 'AME', 'WU', 'ESRX', 'TSCO', 'ZION'],
#  ['GLW', 'JCI', 'MDLZ', 'SIG'],
#  ['SCHW', 'EIX', 'NOC'],
#  ['EQT', 'BRK.B', 'SRE', 'CTAS', 'TXT', 'EMR', 'MNST', 'RRC'],
#  ['INFO', 'ROP', 'HII', 'NEE', 'IFF'],
#  ['EMR', 'SYK', 'ALGN', 'CELG', 'DUK', 'MON', 'BLK', 'PDCO', 'PVH'],
#  ['AZO', 'KLAC', 'CELG', 'CVS'],
#  ['ULTA', 'CTXS', 'IBM', 'RCL', 'BAC', 'LUK', 'HAL', 'GWW', 'TXN'],
#  ['ES', 'PLD', 'COL', 'DFS', 'DWDP', 'XEC', 'TSN'],
#  ['MO', 'NAVI', 'ADBE', 'RE', 'COG', 'ROK', 'GS'],
#  ['AAL', 'IQV', 'WBA', 'HUM', 'K', 'HOLX'],
#  ['APA', 'DGX', 'DVN', 'CBG', 'LOW', 'WMT', 'FL', 'V', 'BLL'],
#  ['PRGO', 'JBHT', 'LKQ', 'COO', 'WYNN'],
#  ['GS', 'PRGO', 'PX', 'COL'],
#  ['PCAR', 'PPG', 'AJG', 'BXP', 'MON', 'DHI', 'SIG'],
#  ['MO', 'PSX', 'CTXS', 'AAPL', 'LOW'],
#  ['COP', 'IQV', 'FLIR', 'NOV', 'CBOE', 'V', 'COG', 'MET', 'CL'],
#  ['DLTR', 'EVHC', 'ORCL'],
#  ['APH', 'CMCSA', 'XL', 'SBAC', 'TEL', 'CTAS', 'NWSA', 'SRCL'],
#  ['UNP', 'SLG', 'VNO', 'JCI'],
#  ['ABBV', 'IFF', 'XEC', 'BHF'],
#  ['F', 'KORS', 'BSX'],
#  ['BLK', 'ZTS', 'GM', 'URI', 'DLTR', 'MNST'],
#  ['GE', 'PRGO', 'ALXN', 'XYL', 'CVS', 'LEN', 'SIG', 'NLSN', 'WU'],
#  ['CMA', 'MO', 'HCA', 'TMK', 'VLO', 'DIS'],
#  ['LEN', 'BBY', 'SIG'],
#  ['DPS', 'RF', 'LB', 'AWK', 'DRI'],
#  ['PEP', 'TRIP', 'DE', 'STZ'],
#  ['T', 'SCHW', 'ES', 'VAR', 'IVZ', 'SYMC', 'NCLH', 'GPN'],
#  ['GOOGL', 'V', 'ALGN'],
#  ['OMC', 'VRSK', 'HPQ', 'MU', 'ICE', 'CBS'],
#  ['PM', 'DOV', 'SRE', 'ROST', 'AWK', 'PPG'],
#  ['VMC', 'AMZN', 'T'],
#  ['FDX', 'VLO', 'LNC', 'COF', 'UNP', 'INCY', 'ICE', 'BK', 'DTE'],
#  ['A', 'HSY', 'CMA', 'KEY', 'DOV', 'FITB'],
#  ['COST', 'SNPS', 'SNA', 'JPM'],
#  ['IFF', 'ABC', 'TSN', 'NRG', 'WFC'],
#  ['JWN', 'TPR', 'DIS', 'CDNS', 'EBAY', 'AZO', 'ED', 'OKE', 'UAL'],
#  ['DXC', 'SPGI', 'SBUX', 'GILD', 'AMD', 'QCOM', 'HRL'],
#  ['HCN', 'HES', 'EXPD', 'INTC', 'PWR'],
#  ['GPN', 'CINF', 'COTY', 'APA', 'MAA', 'JNPR', 'SNPS', 'SHW', 'STI'],
#  ['MLM', 'FB', 'TSS', 'VNO', 'CAT'],
#  ['DISH', 'FMC', 'STI', 'MA', 'COG', 'GPS', 'IP', 'DVA', 'AVGO'],
#  ['BWA', 'ETN', 'UNH', 'BAX', 'NEM', 'CTSH'],
#  ['APTV', 'BIIB', 'HRS', 'VFC'],
#  ['EMR', 'MRO', 'USB', 'PDCO', 'PFE'],
#  ['PSX', 'FIS', 'ORCL', 'KSU', 'JNPR', 'QCOM', 'PNR', 'AEE', 'HST'],
#  ['ZION', 'NSC', 'CHD', 'CXO', 'TXN', 'NAVI', 'ULTA', 'T', 'HCA'],
#  ['PWR', 'HOG', 'CELG', 'DTE', 'VFC', 'PPG', 'GPN', 'ESS'],
#  ['HES', 'CELG', 'O', 'MAS', 'XEC'],
#  ['ROK', 'RE', 'PPL'],
#  ['JNPR', 'SBUX', 'HOG'],
#  ['HUM', 'T', 'WYN'],
#  ['CNP', 'AJG', 'WMT'],
#  ['AEP', 'BSX', 'CHK', 'FISV', 'TEL', 'KO'],
#  ['EMN', 'APA', 'DVA', 'LNC', 'NCLH', 'RSG'],
#  ['FFIV', 'CHTR', 'ROP', 'EXPD', 'TXN', 'APD'],
#  ['VNO', 'D', 'SLG', 'MDT'],
#  ['MCK', 'VRSN', 'DVA', 'MLM'],
#  ['HII', 'ARE', 'DHI', 'CMI', 'XEL', 'BHF', 'URI', 'M'],
#  ['BK', 'PM', 'DLR', 'DAL', 'NAVI', 'COF', 'ALLE', 'SHW'],
#  ['UNP', 'RJF', 'UA', 'MAA'],
#  ['COL', 'CI', 'KSS', 'AIV', 'PNC', 'FTI', 'BBT', 'XRX'],
#  ['DVN', 'NI', 'SNPS', 'CHTR'],
#  ['WRK', 'EW', 'FISV', 'PFG', 'VFC', 'AEE', 'ANSS', 'VNO'],
#  ['EXR', 'MS', 'PX', 'WLTW', 'EIX', 'ALB'],
#  ['UTX', 'WYN', 'ALLE', 'ROK', 'OMC', 'IFF', 'DUK', 'KEY', 'ALL'],
#  ['ETR', 'BMY', 'LEG', 'CME'],
#  ['HOLX', 'JNJ', 'T', 'UNM', 'SRE', 'FMC', 'DHI', 'K'],
#  ['AMP', 'HSIC', 'AFL', 'FRT', 'AIV'],
#  ['BHF', 'D', 'KEY', 'PG', 'NOV', 'CMG', 'TRV', 'BLL'],
#  ['DAL', 'HSY', 'SLG', 'COL', 'SRCL', 'VMC', 'HPE'],
#  ['JCI', 'KMI', 'AGN', 'XYL', 'HD', 'MSI', 'VMC', 'CAT', 'UAL'],
#  ['PHM', 'PRGO', 'KEY'],
#  ['IBM', 'PKI', 'CDNS', 'GPC', 'TAP', 'SRCL', 'WHR', 'HBI'],
#  ['MSI', 'ANSS', 'WAT', 'UPS', 'MSFT', 'ROST', 'HPE'],
#  ['WAT', 'WDC', 'HII', 'EOG', 'MRK', 'KEY', 'NKE', 'MPC'],
#  ['UTX', 'CBG', 'CLX', 'BF.B', 'NFLX'],
#  ['UA', 'PCG', 'SYF', 'BRK.B'],
#  ['PSA', 'USB', 'REG', 'RTN', 'AAP', 'EW', 'PGR'],
#  ['CPB', 'ABT', 'CBOE', 'WLTW', 'PCLN', 'DUK'],
#  ['KSU', 'AON', 'DXC', 'INFO', 'D', 'PBCT', 'AFL'],
#  ['DHR', 'WEC', 'SRE', 'PWR'],
#  ['AKAM', 'SHW', 'BAX', 'ROST', 'L', 'SYY'],
#  ['KR', 'XL', 'EXPD', 'HCN', 'ANTM', 'WDC', 'NCLH'],
#  ['ADS', 'NFX', 'SRCL'],
#  ['BBY', 'SWK', 'FMC', 'KMB', 'COL'],
#  ['JBHT', 'PKG', 'UA', 'BIIB', 'HAL', 'BAX', 'GOOGL', 'ETN'],
#  ['PXD', 'AON', 'GPC'],
#  ['ISRG', 'BXP', 'AVGO', 'TDG', 'AAL', 'EQIX', 'KMI', 'DISH', 'MAC'],
#  ['RCL', 'L', 'TRV', 'DLR', 'FLIR'],
#  ['PLD', 'CSRA', 'CDNS', 'DIS', 'CTL'],
#  ['DTE', 'GE', 'BSX', 'AMP', 'VRSK', 'IVZ'],
#  ['MO', 'FMC', 'AVY', 'UAL'],
#  ['COO', 'BF.B', 'IPG', 'EQT'],
#  ['XRX', 'EVHC', 'KMB'],
#  ['JEC', 'APH', 'VRTX', 'TJX', 'CTSH', 'CDNS'],
#  ['TPR', 'HOG', 'BMY', 'INTC', 'ITW', 'LH', 'NEE'],
#  ['MRO', 'T', 'UNM'],
#  ['IR', 'MCK', 'DISCK', 'MAS', 'FLIR', 'COO', 'CFG', 'HSIC'],
#  ['GRMN', 'BAX', 'ORCL', 'HPQ', 'VRSN', 'URI'],
#  ['SO', 'CVX', 'EXC', 'ACN', 'BBY', 'AES'],
#  ['LB', 'SYF', 'OMC', 'DG', 'IFF', 'PHM', 'PX'],
#  ['UDR', 'MCHP', 'CHK', 'SNA'],
#  ['LMT', 'CBG', 'DAL', 'RRC', 'WBA', 'EQIX'],
#  ['CTSH', 'FAST', 'PRU', 'EW'],
#  ['EFX', 'HAL', 'PG', 'BBT'],
#  ['EBAY', 'NEE', 'MKC', 'HCA', 'VRSN', 'ROST', 'ED', 'ALK', 'ITW'],
#  ['LLL', 'IFF', 'IQV', 'PAYX', 'CB', 'USB', 'NKE', 'PBCT', 'VRSK'],
#  ['CMCSA', 'OKE', 'RCL', 'CSCO', 'EBAY', 'BHF', 'EFX'],
#  ['MLM', 'FAST', 'INTC', 'PX', 'WMT'],
#  ['MAA', 'UHS', 'DAL', 'CA', 'NWL', 'INCY'],
#  ['EBAY', 'XOM', 'BRK.B', 'JWN', 'DISH', 'PX'],
#  ['GGP', 'ALK', 'ORCL', 'LKQ', 'DAL', 'SYMC', 'FLIR'],
#  ['IRM', 'URI', 'AKAM'],
#  ['ESRX', 'ABT', 'ALK'],
#  ['PKI', 'MO', 'NCLH'],
#  ['RCL', 'VFC', 'REG', 'VRSN', 'BMY', 'CRM'],
#  ['NDAQ', 'ISRG', 'ADP', 'LYB', 'PCG', 'CMCSA', 'WY'],
#  ['WFC', 'MAC', 'LNC', 'TXN', 'DISH'],
#  ['RJF', 'ALB', 'PEG', 'ETN', 'PSX', 'LMT', 'ABBV', 'MAA'],
#  ['MHK', 'DVN', 'CAH', 'F', 'BA', 'INFO', 'IPG', 'HCN', 'IR'],
#  ['STX', 'CMG', 'EQT', 'MAR', 'DPS', 'PFG'],
#  ['JCI', 'ES', 'AMGN', 'BHGE', 'PXD', 'FOX', 'GLW', 'NTAP'],
#  ['ARNC', 'LYB', 'JNPR', 'ABT', 'BIIB'],
#  ['MTB', 'ADSK', 'BMY', 'APD', 'APA', 'LRCX'],
#  ['GLW', 'HLT', 'WM', 'TSN', 'F', 'COTY', 'AFL', 'CMA'],
#  ['ETFC', 'ITW', 'PDCO', 'SIG', 'FE', 'AET', 'AVGO', 'CHTR'],
#  ['ALGN', 'MTB', 'DISH', 'AEP', 'EMR', 'EIX', 'MAC', 'GPC', 'DUK'],
#  ['GGP', 'ALK', 'IT', 'MMM', 'KSU', 'ESRX', 'BXP'],
#  ['CMA', 'KHC', 'MON', 'COST', 'MKC'],
#  ['EQR', 'ATVI', 'AAPL', 'PSA', 'PX'],
#  ['PVH', 'SEE', 'OXY', 'AVB', 'HAS'],
#  ['SEE', 'BIIB', 'WBA', 'BWA', 'WYNN', 'HSIC', 'ILMN'],
#  ['EMN', 'HES', 'OXY', 'K', 'SYK', 'PRU', 'BWA', 'AMZN'],
#  ['BSX', 'UPS', 'HCN', 'TDG', 'ACN', 'ADSK'],
#  ['FCX', 'ED', 'VLO'],
#  ['RTN', 'TAP', 'SWKS', 'COF', 'SYK', 'PNW', 'XEC', 'PLD', 'RJF'],
#  ['NTRS', 'EQIX', 'LLL', 'MTD', 'AON', 'HCN', 'PLD'],
#  ['XRX', 'NKE', 'FISV'],
#  ['IPG', 'C', 'CELG', 'XEL', 'HRL', 'EA', 'ALXN', 'ADBE'],
#  ['SYMC', 'MYL', 'AGN', 'HAS', 'MCO', 'WRK', 'CBG'],
#  ['SJM', 'ALB', 'CVS', 'ANSS', 'EXC', 'CELG', 'AMG', 'LRCX', 'TXT'],
#  ['UTX', 'BLK', 'DIS', 'PCAR'],
#  ['CSX', 'SRE', 'AEE', 'NCLH', 'PFE', 'KR'],
#  ['TRV', 'AMT', 'MDT', 'SRCL', 'CL', 'GIS', 'ANDV', 'BA'],
#  ['ZION', 'MO', 'BHGE', 'MYL', 'ILMN'],
#  ['HON', 'FBHS', 'DTE', 'AKAM'],
#  ['LH', 'AAL', 'AMZN', 'FOX', 'APC', 'PG', 'DHR'],
#  ['HRB', 'WM', 'ABC', 'NOC', 'PSA', 'CL', 'LEG'],
#  ['CMG', 'IQV', 'ATVI'],
#  ['WRK', 'GIS', 'GOOGL', 'AXP', 'SHW'],
#  ['ZTS', 'ACN', 'PPL', 'NCLH', 'TSS'],
#  ['STZ', 'MLM', 'FTV', 'KORS', 'JCI', 'UNH'],
#  ['GT', 'VFC', 'PKG', 'KR', 'COF'],
#  ['HON', 'ABC', 'LUK', 'CELG', 'DRI', 'GPN', 'ROP'],
#  ['WM', 'BRK.B', 'VRSN', 'MDLZ', 'ETN', 'DIS', 'FISV', 'PDCO'],
#  ['LUK', 'QRVO', 'CDNS', 'ABC', 'LKQ', 'CMS', 'DFS', 'DISCK', 'ROK'],
#  ['AOS', 'AAL', 'SYY', 'COTY'],
#  ['NUE', 'RE', 'MOS', 'O', 'DFS', 'PAYX', 'HAS'],
#  ['MCK', 'IFF', 'PHM'],
#  ['MAT', 'KHC', 'PNC'],
#  ['GWW', 'XOM', 'SLG', 'EQR', 'FRT', 'PYPL', 'SWK', 'CA'],
#  ['MAS', 'BIIB', 'UTX', 'PFG'],
#  ['WHR', 'NCLH', 'LUV', 'TROW', 'CELG', 'GD', 'TMO'],
#  ['NAVI', 'IBM', 'HBI', 'ALK', 'IP', 'ATVI', 'K'],
#  ['RCL', 'EIX', 'HRB', 'TSS', 'RHT'],
#  ['BAC', 'INTC', 'KO', 'PXD', 'ABT', 'CMI'],
#  ['WU', 'MAA', 'PPG'],
#  ['UAA', 'CAH', 'STZ', 'NCLH', 'IDXX'],
#  ['GT', 'XRX', 'AZO', 'BDX'],
#  ['NWSA', 'AYI', 'BBT', 'BLK', 'OMC', 'MHK'],
#  ['IBM', 'BBT', 'AIZ'],
#  ['PNW', 'AEP', 'PM', 'FL'],
#  ['SRE', 'DIS', 'GIS', 'MDT', 'IP', 'TEL'],
#  ['SNI', 'LEG', 'HCA', 'CVX', 'EQT'],
#  ['CAG', 'BEN', 'VIAB', 'SNPS', 'BDX', 'HBI', 'GPN', 'GIS', 'VFC'],
#  ['GT', 'ALGN', 'ADBE', 'SEE'],
#  ['WHR', 'UDR', 'NVDA', 'RJF', 'BHGE', 'MCD', 'MAA', 'IT', 'PLD'],
#  ['UDR', 'COG', 'KORS', 'WEC', 'AAL', 'CSX', 'JNPR', 'JCI'],
#  ['PSA', 'DVN', 'AVY', 'GPC', 'COG'],
#  ['KMB', 'HAL', 'HCA'],
#  ['CFG', 'DHI', 'AMAT', 'MSI', 'GGP', 'XYL'],
#  ['MGM', 'AZO', 'CHD', 'URI', 'PFE'],
#  ['CMI', 'DAL', 'ARNC', 'EQT', 'ORCL', 'MDLZ', 'APH', 'COO', 'LNC'],
#  ['CAG', 'PRU', 'DVN', 'MAC', 'ABT', 'ADP', 'VTR'],
#  ['COP', 'HRS', 'ETN', 'NI', 'BBY', 'ABC'],
#  ['HPQ', 'GWW', 'VTR', 'LLL', 'MSI', 'TRV', 'APC'],
#  ['AGN', 'UAA', 'NWL', 'NWSA', 'KORS'],
#  ['SYK', 'UNH', 'BHGE', 'ROK', 'LLL', 'NTRS', 'AGN', 'NKE'],
#  ['OMC', 'SYY', 'KEY', 'VRTX'],
#  ['DIS', 'ADSK', 'SRCL', 'AAPL', 'CFG', 'HSIC', 'CMG', 'CMS'],
#  ['PHM', 'INCY', 'CTSH', 'INTU'],
#  ['PEG', 'LLL', 'COF', 'AAPL', 'F', 'TXT', 'PX'],
#  ['UTX', 'F', 'DVN', 'HCP', 'NEE', 'TWX', 'GM'],
#  ['KMX', 'ALXN', 'KMB', 'RMD', 'AMD'],
#  ['HBAN', 'MOS', 'SPGI', 'CTL', 'OMC', 'WU'],
#  ['ETFC', 'ALK', 'TRV', 'AMD', 'ISRG', 'CNC', 'XL', 'LEN', 'AES'],
#  ['ROK', 'PCLN', 'KEY', 'AOS', 'DLTR', 'ABC', 'WBA', 'AKAM'],
#  ['JNJ', 'HRL', 'MU', 'PXD', 'SHW', 'BWA', 'MSFT'],
#  ['BEN', 'NOC', 'TWX', 'PEG', 'HUM', 'HPQ'],
#  ['TXT', 'UNH', 'RMD', 'BEN', 'ROP', 'JPM', 'CME', 'ICE'],
#  ['BDX', 'EXPE', 'CDNS'],
#  ['MPC', 'GM', 'WFC', 'PRU', 'NEM', 'KMB'],
#  ['GOOGL', 'ANTM', 'KMX'],
#  ['DE', 'ADSK', 'EQR', 'PEG', 'HST', 'COST', 'LOW', 'MYL', 'PRU'],
#  ['PNC', 'ECL', 'TXT'],
#  ['COG', 'FTI', 'PX', 'MTD'],
#  ['CMS', 'LEG', 'CBOE', 'EVHC', 'VAR', 'IDXX'],
#  ['FAST', 'MSI', 'FDX', 'HSY', 'PFE', 'DXC', 'NEE'],
#  ['EXPE', 'CSRA', 'TMK', 'AEE', 'DE'],
#  ['AZO', 'DVA', 'AMZN', 'PHM', 'EW', 'CF', 'JNPR'],
#  ['WY', 'WAT', 'ANSS'],
#  ['BHGE', 'STX', 'VNO', 'BIIB'],
#  ['LMT', 'WRK', 'HBAN'],
#  ['SNPS', 'BSX', 'DVA', 'EFX', 'DPS', 'CHD', 'RSG'],
#  ['MAC', 'MMC', 'NDAQ', 'HAS', 'VRTX', 'HIG'],
#  ['AES', 'COST', 'AMD', 'WU', 'PEP', 'AMGN', 'DHR', 'INTC'],
#  ['C', 'AMZN', 'PG'],
#  ['CBS', 'MO', 'ORCL', 'ROK'],
#  ['COTY', 'CL', 'SLB', 'AVGO', 'AEP'],
#  ['AVGO', 'APA', 'RHT', 'DLTR'],
#  ['BBT', 'INCY', 'PNR'],
#  ['CHRW', 'EXPD', 'SO'],
#  ['HBI', 'AXP', 'RSG'],
#  ['SJM', 'PPG', 'WMT', 'CHK', 'CVS', 'LLL'],
#  ['LB', 'TMO', 'GOOGL', 'AXP', 'INCY', 'STZ', 'HCP', 'ADSK', 'RTN'],
#  ['ALL', 'ESS', 'LEN', 'CHRW', 'SCG', 'PDCO', 'BIIB'],
#  ['GPC', 'ORCL', 'AMGN', 'APA', 'CXO', 'LNC', 'SLG', 'AEP', 'VMC'],
#  ['VLO', 'ETN', 'CXO', 'GT', 'JNJ', 'AES', 'APTV', 'DXC', 'EW'],
#  ['ABC', 'CHD', 'NWS', 'BDX', 'SLB', 'PNR', 'ECL'],
#  ['LB', 'MSFT', 'BHGE', 'HUM', 'EQR', 'FRT', 'PBCT', 'USB', 'BF.B'],
#  ['ABT', 'CMG', 'MPC', 'CMS', 'FL', 'MU'],
#  ['FOXA', 'TROW', 'EQR', 'MCO', 'CSX', 'PWR', 'AOS', 'FITB'],
#  ['GILD', 'TRIP', 'DLTR', 'NAVI', 'AES', 'IQV', 'HCP', 'EL'],
#  ['SYF', 'FIS', 'MDLZ', 'WYN', 'CHK'],
#  ['AAL', 'COL', 'ULTA', 'CINF', 'FLR', 'HII', 'MAR', 'CDNS'],
#  ['SPGI', 'CINF', 'CBG', 'AAP', 'COTY', 'LB', 'GLW'],
#  ['APA', 'LB', 'TSS', 'BA', 'BSX', 'DVN', 'SIG', 'CHD'],
#  ['ETR', 'MOS', 'ES', 'VLO'],
#  ['HOG', 'COO', 'COTY', 'AIG'],
#  ['ABT', 'RTN', 'PWR', 'UNP', 'BA', 'CHK'],
#  ['ESRX', 'BAC', 'SYY', 'ANTM', 'SIG'],
#  ['K', 'ALL', 'WY', 'MAT', 'FBHS', 'FFIV', 'ESS', 'COO', 'PXD'],
#  ['CVX', 'PG', 'PWR', 'VRSN', 'MAA', 'AET', 'NVDA', 'DPS', 'FTV'],
#  ['TPR', 'ANDV', 'AYI', 'COTY', 'WFC', 'HES'],
#  ['AMZN', 'SWK', 'AMG'],
#  ['MAS', 'ICE', 'BMY', 'WY', 'CXO', 'XRAY', 'RE'],
#  ['ACN', 'NI', 'WDC', 'SYMC', 'STX', 'AXP', 'T', 'DVN', 'UHS'],
#  ['ABC', 'XL', 'EQT', 'PH', 'GPN', 'SLG'],
#  ['BHGE', 'GIS', 'HII'],
#  ['BSX', 'TSCO', 'COG', 'SHW', 'VAR', 'DOV', 'BDX'],
#  ['LRCX', 'ALK', 'PGR', 'AIV', 'PKI', 'UTX', 'AFL', 'K'],
#  ['NSC', 'NDAQ', 'OXY', 'FFIV', 'WBA', 'TMK', 'TMO', 'APC'],
#  ['WU', 'DLTR', 'MDLZ', 'TWX', 'KR'],
#  ['MDLZ', 'AVGO', 'JWN', 'NWSA'],
#  ['LOW', 'MON', 'GD'],
#  ['KIM', 'CELG', 'ROP', 'CSCO'],
#  ['ABC', 'DVN', 'FIS', 'ALB', 'GD', 'ORCL', 'HON', 'UA', 'TMK'],
#  ['NDAQ', 'ARNC', 'IR', 'BDX', 'NVDA', 'AIG', 'EBAY', 'D', 'ABT'],
#  ['XEL', 'LUV', 'MLM', 'GT', 'CMCSA', 'UAA'],
#  ['CMCSA', 'MAR', 'BHGE', 'XL', 'HUM'],
#  ['MAT', 'TIF', 'LLY', 'CHRW', 'DXC', 'CME', 'GPS', 'ALB'],
#  ['OXY', 'EA', 'BAC', 'AMG', 'IPG', 'UA', 'EL'],
#  ['DFS', 'WY', 'MYL', 'INFO', 'FE', 'EBAY', 'KLAC', 'DUK', 'CCL'],
#  ['HII', 'SHW', 'F', 'FBHS'],
#  ['PSX', 'LEG', 'FRT'],
#  ['WYNN', 'DLR', 'CBG', 'MSFT', 'ZBH'],
#  ['CINF', 'EXR', 'JBHT'],
#  ['LRCX', 'LYB', 'CB', 'ALK', 'COTY'],
#  ['AMAT', 'MCD', 'BHF', 'BAC', 'AKAM', 'EFX', 'HRB'],
#  ['PRU', 'CMS', 'UPS', 'SJM', 'DHI', 'WEC', 'CRM', 'MPC', 'DLR'],
#  ['TROW', 'DISH', 'HOLX', 'XL', 'CFG', 'OXY', 'WBA'],
#  ['CELG', 'VAR', 'INTC', 'DVN'],
#  ['REGN', 'TIF', 'IDXX', 'CNP', 'HON', 'MHK', 'AJG'],
#  ['KLAC', 'ACN', 'NEE', 'ETN', 'UDR', 'CTAS', 'BIIB', 'NWS', 'PRGO'],
#  ['GPC', 'HRS', 'CHK', 'HCA'],
#  ['MNST', 'XOM', 'APD', 'KSS', 'CA', 'BSX', 'HP'],
#  ['SRCL', 'TSS', 'NRG', 'EXPE', 'URI', 'UHS', 'LEG'],
#  ['JBHT', 'HPE', 'EBAY', 'DGX'],
#  ['UDR', 'KORS', 'ORCL', 'COTY', 'K', 'AJG'],
#  ['IP', 'MCO', 'UDR'],
#  ['CCL', 'JWN', 'IQV', 'MCK', 'REG'],
#  ['DISCA', 'CHTR', 'FE', 'AVB', 'ANSS', 'IFF', 'ALXN', 'QCOM'],
#  ['MTD', 'HST', 'UNP', 'JCI', 'FDX', 'NOV', 'PAYX', 'T'],
#  ['TSN', 'GPN', 'XRX', 'NOC'],
#  ['CPB', 'TXN', 'TIF', 'BAX', 'ETFC', 'EMN'],
#  ['HRB', 'HOLX', 'GWW', 'M', 'XEL', 'CL'],
#  ['PBCT', 'CDNS', 'ZBH', 'NWS', 'GGP'],
#  ['GGP', 'VMC', 'EBAY', 'DGX', 'CELG'],
#  ['FTI', 'AMP', 'EQT', 'JWN', 'APH', 'MO', 'PM', 'ES', 'NCLH'],
#  ['KO', 'IVZ', 'HUM', 'NEE', 'FFIV', 'SNA', 'ESRX'],
#  ['DISH', 'ARNC', 'HSY', 'AON'],
#  ['EBAY', 'CSX', 'SBAC', 'WYN', 'MTD', 'CTXS', 'BIIB', 'CL', 'VRSN'],
#  ['UAA', 'DRE', 'AAL', 'APA', 'NWSA', 'OMC', 'HAS', 'ROK', 'ICE'],
#  ['STX', 'AGN', 'PCLN', 'MSI', 'QCOM', 'TSCO'],
#  ['REG', 'TSS', 'GPS', 'CCI', 'ADP', 'KLAC'],
#  ['CLX', 'MOS', 'DVA'],
#  ['RHT', 'LMT', 'HCN'],
#  ['BBY', 'IRM', 'CI', 'XLNX', 'COP', 'ATVI', 'MU', 'INTU', 'AAPL'],
#  ['VNO', 'HBI', 'GOOG', 'KMB', 'CA'],
#  ['CRM', 'PPG', 'TWX', 'VMC', 'CSCO', 'NEE', 'PEG', 'NEM', 'MRO'],
#  ['ANTM', 'ETR', 'CB', 'NFLX', 'MKC', 'M'],
#  ['EOG', 'GM', 'AON', 'EXR', 'HOLX', 'FL', 'AET'],
#  ['UNM', 'EMR', 'TXN', 'UAA', 'MMC', 'PXD'],
#  ['HII', 'CMA', 'SRCL', 'NSC', 'MCK', 'REG', 'TSCO', 'LRCX', 'INTU'],
#  ['CL', 'KHC', 'SNA', 'PCAR', 'SRE', 'EMR', 'APC'],
#  ['NWL', 'ANSS', 'CRM', 'CHTR', 'COG', 'BRK.B', 'EIX', 'EBAY'],
#  ['PAYX', 'RL', 'DIS', 'CLX', 'ALL'],
#  ['TSN', 'RE', 'SNPS', 'CB', 'LNC', 'CCI', 'ES', 'AOS'],
#  ['GT', 'MMM', 'URI', 'CB'],
#  ['STT', 'AOS', 'NOV', 'LKQ', 'PEP', 'IRM'],
#  ['XEL', 'NVDA', 'FAST', 'IR', 'VRSN', 'WRK'],
#  ['ALK', 'HD', 'PNR', 'HSY', 'SPG', 'C', 'ADS', 'VLO'],
#  ['GOOG', 'MRO', 'CTXS', 'CHRW', 'BBY'],
#  ['SNPS', 'EBAY', 'ITW', 'HBAN'],
#  ['WAT', 'DISCK', 'ARE', 'ABC'],
#  ['ACN', 'ETFC', 'ADM', 'BK', 'AES'],
#  ['EIX', 'DVA', 'TSS', 'MYL', 'XL', 'HPQ', 'PSA', 'PPG', 'STZ'],
#  ['ANTM', 'NWL', 'GGP', 'BLK', 'MAC', 'OKE', 'ROP', 'AVGO'],
#  ['RE', 'PFE', 'PFG', 'CLX', 'FIS', 'CBS', 'DHI'],
#  ['ANDV', 'RRC', 'ETN', 'BLL', 'EMN', 'ETR'],
#  ['MCD', 'CMG', 'ALXN', 'PPL', 'DE', 'HOLX', 'EQIX'],
#  ['CLX', 'VTR', 'LMT'],
#  ['ABT', 'COTY', 'CI', 'HBAN', 'SYMC'],
#  ['LLL', 'INTU', 'NAVI', 'DWDP', 'CL', 'OXY'],
#  ['FRT', 'HUM', 'KEY', 'SWK', 'M', 'SWKS', 'DOV'],
#  ['HAL', 'WEC', 'MSFT', 'MCO', 'PFE'],
#  ['BBY', 'GPN', 'MDLZ', 'CA', 'MON'],
#  ['FMC', 'HCP', 'HLT', 'MPC', 'SIG', 'EMR', 'PCG'],
#  ['VMC', 'ESRX', 'ITW', 'HCN', 'GWW', 'BDX'],
#  ['MON', 'AOS', 'APH'],
#  ['COL', 'FMC', 'YUM'],
#  ['HLT', 'EMR', 'LNT', 'GPN', 'CNC', 'TSCO'],
#  ['JBHT', 'ESS', 'MAA', 'ALL', 'PH', 'UAA'],
#  ['HES', 'CVS', 'XLNX', 'GPN'],
#  ['MDLZ', 'PM', 'ROP', 'VFC', 'ECL', 'IDXX', 'ATVI'],
#  ['DHI', 'SLG', 'ANSS', 'HIG', 'FLIR'],
#  ['NUE', 'XEC', 'ILMN', 'EXC', 'REGN', 'PCLN'],
#  ['CI', 'AIG', 'QCOM', 'CMI', 'EW', 'MGM', 'CF', 'TPR'],
#  ['KHC', 'CAT', 'CMG', 'SO', 'CMI', 'HSIC'],
#  ['GM', 'T', 'MAA', 'FOX', 'ABBV', 'SRE'],
#  ['MMC', 'FLR', 'AZO', 'VRSK'],
#  ['IQV', 'JPM', 'PDCO', 'USB', 'TDG', 'UNM', 'CB'],
#  ['EVHC', 'RSG', 'SBUX', 'VFC', 'NWSA', 'BWA'],
#  ['FISV', 'TRIP', 'AMD', 'NTRS', 'MAT', 'TEL', 'UTX'],
#  ['SHW', 'OKE', 'PSA', 'PSX', 'ARE', 'AFL', 'FE', 'CAG'],
#  ['XOM', 'COP', 'AAP', 'GOOG', 'BLL'],
#  ['UHS', 'MHK', 'ALB', 'NWL'],
#  ['ULTA', 'LKQ', 'TWX', 'EBAY', 'UNH', 'AVGO', 'DVA', 'OKE', 'APA'],
#  ['PDCO', 'AEP', 'FLS'],
#  ['STT', 'ORLY', 'CRM'],
#  ['APH', 'EQIX', 'FTI', 'PEG', 'IDXX', 'F', 'PCAR', 'BXP', 'BHF'],
#  ['HSIC', 'SWK', 'ADI', 'DHR', 'MYL', 'BBY'],
#  ['JPM', 'HP', 'ALGN', 'ES'],
#  ['UTX', 'FLIR', 'HBI', 'CFG', 'CMCSA', 'ROK', 'TSS', 'AIZ'],
#  ['GS', 'APD', 'ALLE', 'RTN', 'NFX', 'MAT', 'FLS'],
#  ['AET', 'NTAP', 'TAP', 'LLY', 'PKG', 'COST', 'CDNS', 'CMCSA'],
#  ['FAST', 'DUK', 'AKAM', 'PNR', 'FLR'],
#  ['BBT', 'AOS', 'PH', 'ALLE', 'HAS', 'GE'],
#  ['RCL', 'AMZN', 'M'],
#  ['GGP', 'ALK', 'COO', 'GPC', 'CBS'],
#  ['HSY', 'AVY', 'HBI', 'GLW', 'CA', 'CCI', 'CAG', 'FISV', 'EVHC'],
#  ['HD', 'CMA', 'TJX', 'AVGO'],
#  ['NFLX', 'PLD', 'REGN', 'STX', 'MNST', 'IQV', 'ALGN', 'ESS', 'BBY'],
#  ['ALLE', 'MAT', 'JPM', 'CHD', 'L', 'DFS', 'MDLZ', 'DE'],
#  ['WYN', 'CAG', 'JNJ', 'CHTR', 'PEG', 'FTI'],
#  ['FITB', 'XEC', 'EXR', 'AON', 'JCI', 'PLD'],
#  ['MCK', 'EXPD', 'HPE', 'TJX', 'DVN', 'PFE'],
#  ['COST', 'VIAB', 'GILD', 'AFL', 'MSFT', 'VLO'],
#  ['HON', 'PH', 'MTB', 'AVGO', 'RCL', 'TMO', 'AES'],
#  ['COTY', 'MMM', 'SLG', 'PCLN', 'DAL'],
#  ['WDC', 'MDT', 'CSCO', 'BXP', 'WAT', 'HSIC'],
#  ['HPQ', 'LMT', 'WU', 'SCG', 'APC', 'GS'],
#  ['WAT', 'DISCK', 'ARNC', 'WLTW'],
#  ['MYL', 'APH', 'CHTR', 'RJF', 'TMO'],
#  ['ILMN', 'PNW', 'F', 'INCY', 'AKAM', 'PCLN'],
#  ['UNH', 'NBL', 'XOM'],
#  ['FISV', 'DAL', 'PKI', 'PVH', 'RHT'],
#  ['XOM', 'KHC', 'CSRA'],
#  ['MNST', 'SLB', 'PRU', 'COTY', 'GIS', 'NEM', 'PLD'],
#  ['CL', 'DWDP', 'NI', 'GWW', 'JEC', 'MAS', 'FB', 'CHK', 'UDR'],
#  ['NBL', 'SCHW', 'APA', 'NAVI'],
#  ['ESRX', 'K', 'GPC', 'GD'],
#  ['BRK.B', 'AMD', 'MDLZ', 'PYPL', 'CBG', 'BDX'],
#  ['MCHP', 'AIG', 'LRCX', 'MGM', 'HAL', 'DISCK', 'NRG'],
#  ['CI', 'DRE', 'BIIB', 'JBHT', 'SIG', 'KEY', 'ALXN', 'AYI'],
#  ['SLB', 'MS', 'DISCK', 'AFL', 'FB', 'WM', 'COF'],
#  ['YUM', 'NOC', 'EMR', 'SNA', 'BA', 'SYY', 'MKC', 'DWDP', 'AAP'],
#  ['SYMC', 'APD', 'LUK', 'LNT', 'XLNX', 'RMD', 'CSRA', 'HOG', 'SHW'],
#  ['GM', 'NWL', 'DHI', 'FE', 'NI', 'MDT', 'GPN'],
#  ['CAH', 'ARNC', 'FMC', 'PRGO', 'FITB', 'RTN'],
#  ['CNC', 'WAT', 'NI', 'FTV', 'T', 'NUE', 'DE', 'ZBH'],
#  ['NOV', 'UAA', 'CDNS'],
#  ['TSN', 'COTY', 'UAA', 'NLSN', 'QRVO', 'UNP'],
#  ['PYPL', 'VRTX', 'BMY'],
#  ['MGM', 'DAL', 'SYMC', 'UNM'],
#  ['FMC', 'EQR', 'TROW', 'ORCL', 'WFC', 'CSRA', 'SPGI', 'HPE', 'CMS'],
#  ['GT', 'FTI', 'V', 'LNT', 'WMB', 'IVZ', 'PNW'],
#  ['AVGO', 'F', 'KMI', 'IVZ', 'UHS', 'PHM', 'K', 'CMA', 'ECL'],
#  ['PNR', 'APC', 'HBAN', 'CLX', 'NOV', 'HP', 'CMG', 'JWN', 'CDNS'],
#  ['NFX', 'CVX', 'FAST', 'IFF', 'JCI', 'BEN'],
#  ['LEN', 'CXO', 'LNT', 'IBM', 'DOV', 'SBUX', 'WM', 'HPQ', 'ADM'],
#  ['DLR', 'JEC', 'IPG'],
#  ['HOLX', 'OXY', 'UHS'],
#  ['CDNS', 'SYF', 'FTI'],
#  ['ESS', 'CBG', 'AMD', 'PH', 'RHT'],
#  ['ITW', 'RMD', 'APA', 'BRK.B', 'CHRW'],
#  ['USB', 'MON', 'MGM', 'MMC', 'GM', 'ABBV', 'HIG', 'PCAR', 'ABT'],
#  ['KIM', 'LMT', 'GOOG', 'VNO'],
#  ['ETFC', 'SEE', 'WYNN', 'XRAY', 'SYMC'],
#  ['ALGN', 'APTV', 'PFG', 'FAST', 'HES', 'VAR', 'MSFT', 'PCG', 'HIG'],
#  ['MRO', 'UTX', 'MCO', 'TDG', 'USB', 'JBHT'],
#  ['AMD', 'SIG', 'ADBE', 'VRSK', 'FOXA', 'DVN', 'FE', 'CMS'],
#  ['GWW', 'ICE', 'UNP', 'SWK', 'PNW'],
#  ['KORS', 'MMM', 'LLL', 'M'],
#  ['JNJ', 'BBT', 'UHS', 'PH', 'RCL', 'PXD'],
#  ['MU', 'VZ', 'MAC', 'JWN', 'YUM', 'WLTW'],
#  ['TSN', 'AMP', 'AME'],
#  ['FITB', 'SCHW', 'MNST', 'OMC', 'DUK'],
#  ['UNP', 'HES', 'COL'],
#  ['MKC', 'PAYX', 'TEL'],
#  ['OMC', 'HRB', 'XEL', 'LKQ', 'APC', 'DRE', 'PVH', 'XRAY'],
#  ['AMG', 'NRG', 'EIX', 'KSS', 'MRK', 'NI'],
#  ['WMB', 'FLS', 'ETFC'],
#  ['ANDV', 'CB', 'ALGN', 'INCY', 'DUK', 'PDCO'],
#  ['MAA', 'GT', 'SRCL', 'PCAR', 'PXD'],
#  ['STX', 'KMI', 'DGX'],
#  ['VRSN', 'PX', 'DLR'],
#  ['MET', 'NWL', 'DISCA', 'CMG', 'NWSA', 'LKQ'],
#  ['VIAB', 'RCL', 'LUV', 'PHM', 'PKG', 'WMB', 'FAST', 'AVY', 'EBAY'],
#  ['CPB', 'BWA', 'KEY'],
#  ['CL', 'XL', 'GOOG', 'D', 'TPR', 'MAA', 'GPS', 'SPGI', 'CB'],
#  ['AAP', 'PCAR', 'JBHT', 'UNH', 'BLK', 'AXP', 'ARE', 'KR'],
#  ['CL', 'MTB', 'ROK', 'CSRA', 'LLL', 'AOS', 'CELG', 'CF'],
#  ['IQV', 'DVA', 'NI', 'SLB', 'VLO', 'PRGO', 'IRM', 'DWDP'],
#  ['BSX', 'LUV', 'AIV', 'FFIV', 'FLS', 'IRM'],
#  ['WHR', 'ECL', 'HCA', 'SYK', 'LUK', 'LKQ', 'CBOE', 'FITB'],
#  ['STI', 'TJX', 'SLB'],
#  ['MA', 'BRK.B', 'PNC', 'AAP', 'CMA', 'ZBH', 'VRTX', 'MDLZ'],
#  ['HUM', 'RL', 'EQT', 'EXPD', 'TSS', 'GGP', 'KSU', 'BLK', 'FMC'],
#  ['AFL', 'FOXA', 'INFO', 'PPL', 'PGR', 'HOG', 'XRAY', 'MNST', 'ALLE'],
#  ['MTB', 'LH', 'STT', 'CL'],
#  ['WBA', 'CTXS', 'BEN'],
#  ['CMA', 'MRK', 'SBAC', 'UNH', 'REG', 'FIS'],
#  ['URI', 'MA', 'CBG', 'BHGE', 'SBUX'],
#  ['SIG', 'PXD', 'IRM', 'LOW', 'VFC', 'AFL', 'CRM', 'V'],
#  ['CHD', 'AIZ', 'ETFC', 'PLD', 'CSCO', 'COO'],
#  ['DFS', 'PNW', 'STX', 'HUM', 'USB', 'UNM'],
#  ['ADP', 'QCOM', 'DVA'],
#  ['BBT', 'ETR', 'AIZ', 'MCO', 'NRG', 'BWA'],
#  ['KORS', 'ISRG', 'SYF', 'UPS', 'PHM', 'OKE', 'ED', 'CHTR', 'ALXN'],
#  ['SWKS', 'FBHS', 'PAYX', 'VZ'],
#  ['PWR', 'PYPL', 'GD', 'PPL', 'HP', 'SYF', 'SIG', 'LUV', 'IRM'],
#  ['PDCO', 'AIV', 'UNH', 'HOG', 'TIF'],
#  ['ABC', 'NBL', 'JNPR', 'NCLH', 'HRL', 'SJM', 'INFO', 'MHK'],
#  ['PDCO', 'CBOE', 'DHI', 'AWK', 'ALL', 'TXT', 'WU', 'C', 'UTX'],
#  ['INFO', 'DWDP', 'DAL', 'RSG'],
#  ['DE', 'TSCO', 'NUE', 'KLAC', 'PH'],
#  ['WU', 'UHS', 'HRL', 'CTXS', 'APD', 'INCY', 'TIF'],
#  ['HIG', 'EA', 'NWSA', 'ANDV', 'AIZ', 'WYNN', 'VRSK', 'KSS', 'MRK'],
#  ['LMT', 'DVN', 'XLNX', 'ETN', 'FIS'],
#  ['MON', 'MO', 'HUM', 'KR', 'SEE', 'EIX'],
#  ['AON', 'DPS', 'ACN', 'HBI', 'CMA', 'CAH', 'EXPE', 'AAL'],
#  ['RMD', 'CSCO', 'SNPS', 'CBOE'],
#  ['LRCX', 'MCD', 'NI'],
#  ['WYN', 'AES', 'BHF', 'MRK', 'RSG'],
#  ['ETN', 'AAL', 'HPE'],
#  ['PEP', 'MON', 'CCI'],
#  ['NEE', 'HBAN', 'ESS', 'ILMN'],
#  ['UDR', 'IPG', 'KR', 'M', 'CFG', 'RF', 'ABBV', 'MU', 'EXPD'],
#  ['ADSK', 'GRMN', 'FLIR', 'ABBV'],
#  ['KHC', 'SYMC', 'CAH', 'COO', 'COTY', 'UAA'],
#  ['STT', 'CHD', 'KSU', 'JPM'],
#  ['CBS', 'UDR', 'PPG', 'ED', 'BHGE', 'AMP'],
#  ['HBI', 'FDX', 'DRI', 'BMY', 'GRMN', 'BXP', 'ORLY', 'MMC', 'JPM'],
#  ['CVX', 'STZ', 'IPG', 'DOV', 'LB', 'CCL', 'FRT', 'MDLZ'],
#  ['CVX', 'CHK', 'AON'],
#  ['BSX', 'SYF', 'ABC', 'DRI', 'COG', 'CXO'],
#  ['SNPS', 'AMD', 'HRS'],
#  ['BWA', 'KIM', 'KSU'],
#  ['USB', 'FITB', 'JEC', 'CSCO', 'SNPS', 'MA', 'TDG', 'TXN', 'ES'],
#  ['ANTM', 'COST', 'AEE', 'CMA', 'ULTA'],
#  ['TPR', 'GWW', 'MAR', 'RHT', 'OXY'],
#  ['NCLH', 'HRB', 'STI'],
#  ['RE', 'KO', 'CSX', 'MCHP', 'GGP'],
#  ['PGR', 'CXO', 'TMO', 'IRM', 'RCL', 'BF.B', 'TAP'],
#  ['PEP', 'USB', 'PH', 'HES', 'CCL', 'PGR', 'DHI', 'UPS', 'UHS'],
#  ['PFE', 'FL', 'EXC', 'MYL', 'RCL', 'CFG'],
#  ['JBHT', 'COO', 'ZION'],
#  ['VIAB', 'PBCT', 'AMGN', 'PFG', 'DLR', 'DVA', 'IFF', 'LNT', 'ES'],
#  ['DLR', 'CAG', 'VMC', 'BWA', 'DOV', 'BEN', 'REGN', 'RHT', 'CI'],
#  ['WEC', 'AME', 'CERN', 'ROST', 'TMO', 'EBAY', 'HD', 'MTD'],
#  ['BBY', 'CFG', 'FLIR', 'MAR'],
#  ['CHD', 'EMN', 'PCG', 'TAP', 'PXD', 'VMC', 'LRCX', 'AMP', 'RCL'],
#  ['ADS', 'DHI', 'KMB', 'ETR', 'LH', 'GRMN', 'LUV'],
#  ['KR', 'CLX', 'ORLY', 'ANDV', 'TPR', 'WMT', 'ULTA'],
#  ['MGM', 'COL', 'UNP', 'TSS', 'DLTR', 'HBI', 'ZBH'],
#  ['NOC', 'KR', 'NLSN', 'GLW', 'HLT', 'WY', 'MCHP'],
#  ['JNPR', 'MTB', 'VRTX'],
#  ['IR', 'AOS', 'PAYX', 'HII'],
#  ['IP', 'PCAR', 'LNC'],
#  ['VIAB', 'GM', 'WU', 'EQR']]

# %% [markdown]
# #### 2.1.3 Generate fake stock position data

# %%
### sample position for one user, eg user holding 3 stocks
eg_positions = []
for i in range(3):
    eg_positions.append(random.uniform(0,1))
[x/sum(eg_positions) for x in eg_positions]
# Out:
# [0.30383973069588055, 0.15613308996919298, 0.5400271793349264]

# %%
### build function to sample positions, input is number of stock holded, output is corresponding position
def sample_position(count):
    positions = []
    for i in range(count):
        positions.append(random.uniform(0,1))
    sum_val = sum(positions)
    return [x/sum_val for x in positions]

# %%
sample_position(3)
# Out:
# [0.47329540900060213, 0.44901451000022025, 0.07769008099917761]

# %%
### loop over every customers
positions = []
for i in num_stocks:
    sampled_positions = sample_position(i)
    positions.append(sampled_positions)

# %% [markdown]
# # Part 3: Save data

# %%
from collections import defaultdict

customer_dic = defaultdict(dict)
for customer,stock, position in zip(list(range(num_customer)),stocks,positions):
    customer_dic[customer]["stocks"] = stock
    customer_dic[customer]['positions'] = position

# %%
import pickle
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
save_obj(customer_dic,"data/customer_data")

# %% [markdown]
# #  Part 4: Modulize

# %%
class data_generator:
    from collections import defaultdict
    import pickle
    import random
    
    def __init__(self,stocksList=None,numHoldingList=None,customeSize=1000):
        self.customeSize = customeSize
        self.stocksList = stocksList
        self.numHoldingList = numHoldingList ### numHoldingList format: [3,4,5,6,7,8,9,10]
    
    def generate_num_stocks(self):
        self.num_stocks = []
        for i in range(num_customer):
            self.num_stocks += sample(self.numHoldingList,1)
            
    def generate_stocks(self):
        self.stocks = []
        for customer,num_stock in zip(range(self.customeSize),self.num_stocks):
            sampled_stocks = sample(list(self.stocksList),num_stock) ### Sample num_stock of stocks from stocks list 
            self.stocks.append(sampled_stocks)
            
    def generate_positions(self):
        self.positions = []
        for i in self.num_stocks:
            sampled_positions = self.sample_position(i)
            self.positions.append(sampled_positions)
            
    def sample_position(self,count):
        positions = []
        for i in range(count):
            positions.append(random.uniform(0,1))
        sum_val = sum(positions)
        return [x/sum_val for x in positions]
    
    def save_as_dict(self):

        self.customer_dic = defaultdict(dict)
        for customer,stock, position in zip(list(range(self.customeSize)),self.stocks,self.positions):
            self.customer_dic[customer]["stocks"] = stock
            self.customer_dic[customer]['positions'] = position
        return self.customer_dic
    
    def generate_data(self):
        self.generate_num_stocks()
        self.generate_stocks()
        self.generate_positions()
        customerDic = self.save_as_dict()
        return customer_dic

# %%
generator = data_generator(customeSize=1000,stocksList=stocksList,numHoldingList=[3,4,5,6,7,8,9,10]) 
customer_data = generator.generate_data()

# %%
customer_data
# Out:
# defaultdict(dict,
#             {0: {'stocks': ['MOS',
#                'MAA',
#                'AMAT',
#                'SNA',
#                'KSU',
#                'GPN',
#                'RHI',
#                'ETR'],
#               'positions': [0.047695681158954874,
#                0.23052107203572847,
#                0.07297433012303643,
#                0.04829579452243989,
#                0.20374682906034589,
#                0.03215473031572561,
#                0.07179900329030696,
#                0.2928125594934619]},
#              1: {'stocks': ['CNC', 'EQR', 'ADM', 'MMC', 'KHC', 'MAA', 'DHI'],
#               'positions': [0.21431997264819516,
#                0.09382397891121017,
#                0.06157383134363061,
#                0.12668594057588903,
#                0.1451204820580555,
#                0.150490801311365,
#                0.2079849931516544]},
#              2: {'stocks': ['GLW',
#                'PM',
#                'INTC',
#                'MAC',
#                'UA',
#                'DG',
#                'AVGO',
#                'CMI'],
#               'positions': [0.11539785163460188,
#                0.1992613353100667,
#                0.1591974033625871,
#                0.011045184683339192,
#                0.02478478755672727,
#                0.16577719225732726,
#                0.16110328378977443,
#                0.16343296140557612]},
#              3: {'stocks': ['MLM', 'BLK', 'INTU', 'WDC', 'JBHT', 'MAA', 'BHF'],
#               'positions': [0.0024661593631594,
#                0.19187973354738092,
#                0.18252925163963296,
#                0.1994338217565041,
#                0.17634353034134076,
#                0.07336322538015831,
#                0.1739842779718236]},
#              4: {'stocks': ['AEE', 'AMGN', 'RE', 'MHK', 'CL'],
#               'positions': [0.34001737242537833,
#                0.0008208805814608346,
#                0.2559214466249283,
#                0.16759193822284002,
#                0.23564836214539264]},
#              5: {'stocks': ['WBA', 'TPR', 'CINF'],
#               'positions': [0.05942584729135006,
#                0.8756165511395699,
#                0.06495760156908004]},
#              6: {'stocks': ['MAA', 'CB', 'AWK', 'TIF', 'PNC'],
#               'positions': [0.2675599493025681,
#                0.22853336909397987,
#                0.10724324542193879,
#                0.2614029238900453,
#                0.13526051229146785]},
#              7: {'stocks': ['CSX', 'M', 'FIS', 'ED', 'ATVI'],
#               'positions': [0.14414497688118338,
#                0.20973596263278332,
#                0.10263784847973251,
#                0.23162341109367926,
#                0.31185780091262155]},
#              8: {'stocks': ['PHM', 'SO', 'DHI'],
#               'positions': [0.49121316393369907,
#                0.3137381269770669,
#                0.19504870908923402]},
#              9: {'stocks': ['LH', 'XEL', 'TIF', 'NFLX', 'MCD', 'LLY'],
#               'positions': [0.372507891335056,
#                0.08034723296945993,
#                0.11211056036192202,
#                0.04058038324175519,
#                0.09027007288241706,
#                0.30418385920938984]},
#              10: {'stocks': ['AMGN',
#                'CINF',
#                'CMG',
#                'MMC',
#                'MAR',
#                'UPS',
#                'FOX',
#                'PCLN',
#                'AAP'],
#               'positions': [0.18244423602164384,
#                0.1763736628400737,
#                0.0023641482637503856,
#                0.0313108251565079,
#                0.12412907310468625,
#                0.05718141995280568,
#                0.17155584701577212,
#                0.10189102234148027,
#                0.15274976530327972]},
#              11: {'stocks': ['MO', 'ILMN', 'ZTS', 'MAT', 'SLB', 'MS'],
#               'positions': [0.08289416000697436,
#                0.11377451970631686,
#                0.22748944357595716,
#                0.24638577001851736,
#                0.14817376883627348,
#                0.18128233785596093]},
#              12: {'stocks': ['COST', 'DRI', 'HES'],
#               'positions': [0.43958207214320166,
#                0.3328049106970143,
#                0.22761301715978416]},
#              13: {'stocks': ['ZBH', 'FLR', 'AXP'],
#               'positions': [0.5526695179651512,
#                0.34527740247221056,
#                0.1020530795626383]},
#              14: {'stocks': ['XEL', 'MCK', 'KORS', 'SRE'],
#               'positions': [0.3947438233332775,
#                0.18362862402060864,
#                0.1523252378091995,
#                0.2693023148369144]},
#              15: {'stocks': ['M', 'ADSK', 'FBHS'],
#               'positions': [0.39369538908443236,
#                0.3649998224700517,
#                0.24130478844551603]},
#              16: {'stocks': ['TSN', 'PSA', 'EXR'],
#               'positions': [0.29987503984664304,
#                0.23543042633292957,
#                0.4646945338204273]},
#              17: {'stocks': ['AAPL', 'UA', 'EA', 'HST', 'DIS'],
#               'positions': [0.20219105365479972,
#                0.28238234472364165,
#                0.1430303183670256,
#                0.35335656601270976,
#                0.019039717241823184]},
#              18: {'stocks': ['MCHP', 'MTB', 'MNST', 'COST'],
#               'positions': [0.6568435070511136,
#                0.05221377795077747,
#                0.2485884540124505,
#                0.04235426098565847]},
#              19: {'stocks': ['ARE',
#                'PWR',
#                'CMG',
#                'JEC',
#                'ETFC',
#                'PM',
#                'FOX',
#                'EBAY',
#                'CB'],
#               'positions': [0.02187239758229521,
#                0.10112559622647586,
#                0.10877013047390965,
#                0.13996566054174758,
#                0.004706405263662232,
#                0.17839514552913102,
#                0.15257743929213685,
#                0.11181402508184732,
#                0.18077320000879443]},
#              20: {'stocks': ['HIG', 'NWS', 'AMGN', 'LKQ', 'EW', 'NEE', 'CLX'],
#               'positions': [0.14209400571187525,
#                0.27028200291243976,
#                0.15040213788428963,
#                0.18344189497698932,
#                0.01762839439663843,
#                0.06632409990089427,
#                0.16982746421687342]},
#              21: {'stocks': ['ORLY', 'TWX', 'SRE', 'F', 'V', 'UAA', 'REG'],
#               'positions': [0.21272468451809012,
#                0.23263896637098697,
#                0.1406141151749808,
#                0.09720393496083236,
#                0.1313518837159268,
#                0.1737141996459125,
#                0.011752215613270459]},
#              22: {'stocks': ['SRCL', 'NRG', 'NSC', 'WM', 'PCG', 'STI'],
#               'positions': [0.26987907181894666,
#                0.07945588145439605,
#                0.08114756776875721,
#                0.04145898427226975,
#                0.3495645769686767,
#                0.17849391771695344]},
#              23: {'stocks': ['PG',
#                'AMT',
#                'AMD',
#                'VRSK',
#                'FAST',
#                'JNPR',
#                'SYMC'],
#               'positions': [0.2599794428085019,
#                0.04932112937138733,
#                0.07628743108314726,
#                0.17837432517179813,
#                0.14913468890253306,
#                0.12057270181238267,
#                0.16633028085024976]},
#              24: {'stocks': ['NOC',
#                'EXPD',
#                'AFL',
#                'MU',
#                'GLW',
#                'MDT',
#                'APTV',
#                'ZION'],
#               'positions': [0.1635091791055976,
#                0.07311569306742091,
#                0.15514456042337074,
#                0.13331594138989286,
#                0.17308376090946317,
#                0.025780394386827814,
#                0.14174129108595235,
#                0.1343091796314745]},
#              25: {'stocks': ['NKE', 'ROP', 'STT', 'HUM'],
#               'positions': [0.14908011037493,
#                0.30352098301386843,
#                0.475527894003186,
#                0.07187101260801554]},
#              26: {'stocks': ['PG', 'MOS', 'MRO', 'SIG', 'AVGO', 'KORS', 'AGN'],
#               'positions': [0.20415872390172335,
#                0.15706592828434152,
#                0.09396133675769251,
#                0.20828582964889916,
#                0.3071442936726911,
#                0.00011817690615652506,
#                0.029265710828495935]},
#              27: {'stocks': ['MAT', 'STI', 'SYK', 'MDT', 'APC', 'CPB'],
#               'positions': [0.20593112695229038,
#                0.16537854270828395,
#                0.20768785565199643,
#                0.2561636374712571,
#                0.13761362699379356,
#                0.02722521022237852]},
#              28: {'stocks': ['TSCO', 'IR', 'XEC', 'COF', 'GWW', 'WRK', 'FLR'],
#               'positions': [0.21846554910884083,
#                0.1901680483587768,
#                0.08888561579865709,
#                0.1230552582315763,
#                0.06943229609847577,
#                0.214103283480432,
#                0.09588994892324118]},
#              29: {'stocks': ['AEE', 'RCL', 'ACN', 'DE', 'DVN'],
#               'positions': [0.03219172201629257,
#                0.2866186781156885,
#                0.6179303015700017,
#                0.03564682045106795,
#                0.027612477846949236]},
#              30: {'stocks': ['BRK.B', 'INTU', 'MU', 'PCAR', 'FMC'],
#               'positions': [0.0014839074977804467,
#                0.18757810113110424,
#                0.1352984711390014,
#                0.34864130829326595,
#                0.32699821193884787]},
#              31: {'stocks': ['DLR', 'DUK', 'EMN', 'ANSS', 'CMA'],
#               'positions': [0.29685558343055796,
#                0.03447339528619662,
#                0.359804041672578,
#                0.28707893591589173,
#                0.021788043694775855]},
#              32: {'stocks': ['EQT', 'AVGO', 'PBCT', 'GWW', 'ABBV'],
#               'positions': [0.06264126915250481,
#                0.16463672855906206,
#                0.27706971033886013,
#                0.2142528895049565,
#                0.28139940244461653]},
#              33: {'stocks': ['UA',
#                'SNPS',
#                'PSX',
#                'AES',
#                'NWSA',
#                'FB',
#                'ZBH',
#                'CMA'],
#               'positions': [0.2389147372670341,
#                0.16585293855317004,
#                0.04143292622374968,
#                0.13778684149840414,
#                0.10491764399158646,
#                0.2086517438051362,
#                0.0980950675463942,
#                0.004348101114525139]},
#              34: {'stocks': ['NBL', 'WMT', 'PSA', 'AIG', 'HBAN'],
#               'positions': [0.19885853911113016,
#                0.20768523314666815,
#                0.21205849390635553,
#                0.17421717289132505,
#                0.20718056094452106]},
#              35: {'stocks': ['MS', 'TMK', 'URI', 'CHRW'],
#               'positions': [0.07481864106194393,
#                0.12920375529770886,
#                0.56549751794207,
#                0.2304800856982773]},
#              36: {'stocks': ['COF',
#                'CHK',
#                'AJG',
#                'GD',
#                'ROST',
#                'CTAS',
#                'WMT',
#                'FRT',
#                'DFS'],
#               'positions': [0.06333843197229673,
#                0.20447833205410562,
#                0.18155460503152368,
#                0.17171260670395275,
#                0.0011654899259165852,
#                0.22563053082013312,
#                0.08175109083130902,
#                0.05452730371596397,
#                0.015841608944798278]},
#              37: {'stocks': ['CVS',
#                'DAL',
#                'MCHP',
#                'QRVO',
#                'PM',
#                'MCD',
#                'AOS',
#                'GS'],
#               'positions': [0.027966948410454124,
#                0.14162298927189412,
#                0.06321412207496878,
#                0.1810441818086048,
#                0.21810826942735947,
#                0.23308854103437368,
#                0.017158868444058728,
#                0.1177960795282864]},
#              38: {'stocks': ['HPQ', 'STT', 'CERN', 'NFLX'],
#               'positions': [0.35029399059525446,
#                0.38452380778328454,
#                0.006627522094046578,
#                0.25855467952741445]},
#              39: {'stocks': ['AWK', 'NUE', 'LEN'],
#               'positions': [0.4721569605979602,
#                0.03774427721711652,
#                0.49009876218492326]},
#              40: {'stocks': ['ADS', 'BAC', 'NSC', 'JBHT', 'TGT'],
#               'positions': [0.38873235222511593,
#                0.2984777943218541,
#                0.03321807912801951,
#                0.15327432051916562,
#                0.12629745380584487]},
#              41: {'stocks': ['JCI', 'BA', 'PEG', 'ALGN'],
#               'positions': [0.272409640875518,
#                0.28982666289150977,
#                0.22641564204702344,
#                0.2113480541859487]},
#              42: {'stocks': ['PKG', 'TROW', 'UAA', 'HRS', 'SO'],
#               'positions': [0.03226968434815529,
#                0.2989348640528298,
#                0.2829211403112855,
#                0.06711573749852187,
#                0.3187585737892073]},
#              43: {'stocks': ['BA', 'KMB', 'COST', 'EIX', 'ALK', 'IRM'],
#               'positions': [0.20237257484755367,
#                0.17849500215342481,
#                0.13859457725165084,
#                0.06324792434640948,
#                0.22275066664749557,
#                0.1945392547534657]},
#              44: {'stocks': ['CHTR', 'K', 'FIS', 'JNPR', 'NLSN', 'AMT'],
#               'positions': [0.28975330417964246,
#                0.020514665401742647,
#                0.30043944835694375,
#                0.2254626376438248,
#                0.16242548797215223,
#                0.0014044564456940352]},
#              45: {'stocks': ['JEC', 'GOOG', 'DVA', 'FOXA', 'CHRW', 'ALL'],
#               'positions': [0.2027298451230436,
#                0.2726358786426379,
#                0.03620585772770274,
#                0.2188164518199744,
#                0.256240341897113,
#                0.013371624789528445]},
#              46: {'stocks': ['AJG',
#                'INCY',
#                'LNC',
#                'ETR',
#                'UAA',
#                'D',
#                'RRC',
#                'DG'],
#               'positions': [0.09871573826427642,
#                0.07142747762799705,
#                0.27313666649544116,
#                0.05190478437822565,
#                0.1272461612231304,
#                0.05493990569270261,
#                0.25460139154045824,
#                0.06802787477776863]},
#              47: {'stocks': ['MYL',
#                'LUK',
#                'URI',
#                'IP',
#                'ESRX',
#                'DRE',
#                'DRI',
#                'SNA',
#                'VRSN'],
#               'positions': [0.20144357196350124,
#                0.009332666707401543,
#                0.19982619874990684,
#                0.07637661924410735,
#                0.06722907067491354,
#                0.07203058594135708,
#                0.10725994893065544,
#                0.193315165818728,
#                0.07318617196942903]},
#              48: {'stocks': ['QCOM', 'MO', 'BAC', 'EBAY', 'SNPS', 'MCHP'],
#               'positions': [0.14128573735199026,
#                0.18050105607249736,
#                0.20195713105346788,
#                0.1744369072381148,
#                0.19086929835032346,
#                0.11094986993360624]},
#              49: {'stocks': ['VRSN',
#                'UAL',
#                'PDCO',
#                'LH',
#                'AKAM',
#                'T',
#                'CBS',
#                'WHR',
#                'ADSK'],
#               'positions': [0.17501646852924863,
#                0.08346918203841686,
#                0.08961649382918153,
#                0.11222647713111045,
#                0.12589702585126053,
#                0.0720965244825492,
#                0.16018927826494836,
#                0.1787465884047645,
#                0.002741961468519956]},
#              50: {'stocks': ['AOS', 'BSX', 'ALK', 'NEM', 'CTAS', 'PYPL'],
#               'positions': [0.2608857524544973,
#                0.16593040648429702,
#                0.003215600274662298,
#                0.2539560753895815,
#                0.08796267262781934,
#                0.22804949276914255]},
#              51: {'stocks': ['AEE', 'AYI', 'WAT', 'AAPL'],
#               'positions': [0.3120474225322318,
#                0.30837687516736795,
#                0.3177062793409214,
#                0.061869422959479024]},
#              52: {'stocks': ['CB', 'TWX', 'GPN'],
#               'positions': [0.20142019578279166,
#                0.6155829058895133,
#                0.1829968983276951]},
#              53: {'stocks': ['AVY', 'GLW', 'AWK'],
#               'positions': [0.41889371639837875,
#                0.4625545398155993,
#                0.11855174378602189]},
#              54: {'stocks': ['REGN', 'LKQ', 'FRT', 'UPS'],
#               'positions': [0.3358527573517454,
#                0.3104208146861029,
#                0.012909986261114063,
#                0.34081644170103764]},
#              55: {'stocks': ['PH', 'HAS', 'TMK', 'ADS', 'AGN', 'EXR'],
#               'positions': [0.004345296831424521,
#                0.053872710911589496,
#                0.38859424335048354,
#                0.15894518942821567,
#                0.12870190621384042,
#                0.2655406532644463]},
#              56: {'stocks': ['NDAQ',
#                'VAR',
#                'GPN',
#                'ZTS',
#                'BF.B',
#                'RTN',
#                'FRT',
#                'PRU',
#                'BHF'],
#               'positions': [0.18373219003888516,
#                0.004694083282840666,
#                0.13685766802027155,
#                0.08231323362654741,
#                0.022957117019660866,
#                0.19274009315425814,
#                0.16489368342560667,
#                0.15614788142365887,
#                0.05566405000827069]},
#              57: {'stocks': ['LH', 'PKG', 'DE', 'KEY', 'NWS'],
#               'positions': [0.09331208812782336,
#                0.3161028931388949,
#                0.34686936021008147,
#                0.11301460177477841,
#                0.1307010567484218]},
#              58: {'stocks': ['APD', 'SLB', 'JEC', 'TMO', 'CCL', 'LYB', 'TSN'],
#               'positions': [0.1399270910225282,
#                0.0847283917206163,
#                0.21903324122841974,
#                0.10248969255589477,
#                0.06269508164294646,
#                0.2917161634711705,
#                0.09941033835842375]},
#              59: {'stocks': ['RF', 'JEC', 'T', 'EIX', 'NFLX', 'DXC'],
#               'positions': [0.18235368487991974,
#                0.09753281316571766,
#                0.21228559288021676,
#                0.12387861483144673,
#                0.22779569458560847,
#                0.15615359965709066]},
#              60: {'stocks': ['XRX', 'NI', 'LEN', 'PFG'],
#               'positions': [0.2699732355398613,
#                0.08533078931192736,
#                0.3997587353415582,
#                0.2449372398066531]},
#              61: {'stocks': ['CVX', 'SCHW', 'XOM', 'BRK.B'],
#               'positions': [0.34166992240160954,
#                0.3115290057910409,
#                0.154395602298506,
#                0.19240546950884355]},
#              62: {'stocks': ['FMC',
#                'SJM',
#                'XYL',
#                'VZ',
#                'ZION',
#                'EMN',
#                'LUV',
#                'MCHP',
#                'SYY'],
#               'positions': [0.06267252427154242,
#                0.10262290052483963,
#                0.09064138512103975,
#                0.1269023622464598,
#                0.1479431957397771,
#                0.06140200324540544,
#                0.1595818583982307,
#                0.07291188450711733,
#                0.17532188594558795]},
#              63: {'stocks': ['MDLZ', 'PFE', 'CBS', 'BAX', 'PDCO', 'EW'],
#               'positions': [0.24761068074581025,
#                0.08136619446288075,
#                0.2727073816668419,
#                0.09354115801314408,
#                0.09405568243519916,
#                0.2107189026761239]},
#              64: {'stocks': ['DE',
#                'MDT',
#                'FCX',
#                'SWK',
#                'TSCO',
#                'CF',
#                'VZ',
#                'TWX'],
#               'positions': [0.0326591488889519,
#                0.18457212980835241,
#                0.19229344255897246,
#                0.017582111889361027,
#                0.1636024453691123,
#                0.1394005848073256,
#                0.15103780341212952,
#                0.11885233326579492]},
#              65: {'stocks': ['SJM', 'AAP', 'MCO', 'KLAC', 'EQR', 'HD', 'ILMN'],
#               'positions': [0.2098657923053409,
#                0.19133875832194844,
#                0.2767248259508551,
#                0.11155543129470191,
#                0.04729196383162677,
#                0.1064219333306235,
#                0.05680129496490336]},
#              66: {'stocks': ['CHK', 'CSCO', 'HLT'],
#               'positions': [0.4150178323819621,
#                0.32254585670146035,
#                0.2624363109165775]},
#              67: {'stocks': ['TRIP', 'AET', 'HAL', 'DAL', 'XLNX'],
#               'positions': [0.19790473325839233,
#                0.19250300572807244,
#                0.06008507876434919,
#                0.31797106149320226,
#                0.23153612075598384]},
#              68: {'stocks': ['SNI', 'VMC', 'ADS'],
#               'positions': [0.14972141362465005,
#                0.014078617843104707,
#                0.8361999685322452]},
#              69: {'stocks': ['KR', 'APD', 'EMR', 'FRT'],
#               'positions': [0.3130239081859078,
#                0.23993856170275116,
#                0.32674212367797234,
#                0.12029540643336861]},
#              70: {'stocks': ['MDLZ', 'BSX', 'FRT', 'PXD'],
#               'positions': [0.31611025841933577,
#                0.2311761645399206,
#                0.22091595462330388,
#                0.23179762241743979]},
#              71: {'stocks': ['WRK', 'DUK', 'TDG', 'CBOE', 'PAYX'],
#               'positions': [0.22425875030981537,
#                0.20917496675899525,
#                0.07324752108075491,
#                0.28843947601494957,
#                0.20487928583548493]},
#              72: {'stocks': ['CMA', 'FITB', 'TAP', 'ACN'],
#               'positions': [0.3895869462236318,
#                0.3176005247293129,
#                0.14715610546619018,
#                0.1456564235808652]},
#              73: {'stocks': ['CDNS',
#                'KLAC',
#                'VRTX',
#                'HAS',
#                'CPB',
#                'NUE',
#                'MET'],
#               'positions': [0.008569929521679629,
#                0.15846820538418052,
#                0.2609814051430604,
#                0.023169954572345757,
#                0.07850659696515033,
#                0.1908153969404791,
#                0.27948851147310433]},
#              74: {'stocks': ['PHM',
#                'PNR',
#                'BEN',
#                'FMC',
#                'TDG',
#                'TRV',
#                'CFG',
#                'NEM'],
#               'positions': [0.1133165704498947,
#                0.25372085589644866,
#                0.03112198720282827,
#                0.18330737239508083,
#                0.057943195850804326,
#                0.09255384759855095,
#                0.14260957943832242,
#                0.12542659116806978]},
#              75: {'stocks': ['NUE',
#                'NVDA',
#                'APA',
#                'RRC',
#                'ANDV',
#                'GWW',
#                'IRM'],
#               'positions': [0.016796239724094962,
#                0.12245139831804701,
#                0.1594460645170917,
#                0.29161693396376104,
#                0.16891811081145477,
#                0.1779571724215442,
#                0.06281408024400623]},
#              76: {'stocks': ['FLIR', 'LNT', 'FL', 'F', 'AXP', 'SHW'],
#               'positions': [0.00949384124628836,
#                0.06174333431742682,
#                0.059943594540570036,
#                0.35789349239268065,
#                0.04022869518578127,
#                0.4706970423172528]},
#              77: {'stocks': ['CA',
#                'CFG',
#                'UA',
#                'OMC',
#                'MCK',
#                'ANDV',
#                'PNR',
#                'AME'],
#               'positions': [0.028467706307502748,
#                0.27305593047576016,
#                0.0938940153060707,
#                0.06255992053321466,
#                0.05522559611840188,
#                0.1605868493986764,
#                0.032391703403530085,
#                0.29381827845684333]},
#              78: {'stocks': ['LEG', 'CAH', 'AET', 'MAC'],
#               'positions': [0.2422345342063585,
#                0.28272366453447256,
#                0.43084362934645687,
#                0.044198171912712025]},
#              79: {'stocks': ['DLTR',
#                'PRU',
#                'PLD',
#                'ARE',
#                'DIS',
#                'NI',
#                'SLB',
#                'DG'],
#               'positions': [0.11159065279463136,
#                0.0875698569138716,
#                0.16100706517457705,
#                0.1887664950633793,
#                0.12547122954968742,
#                0.05476084275270043,
#                0.06475808907833404,
#                0.20607576867281874]},
#              80: {'stocks': ['PLD', 'V', 'IQV'],
#               'positions': [0.006936497396878812,
#                0.6204245156568613,
#                0.37263898694625985]},
#              81: {'stocks': ['HII', 'HON', 'HD', 'XYL', 'HAL'],
#               'positions': [0.290032114676774,
#                0.39833859338114525,
#                0.04808142086066774,
#                0.13228268301698287,
#                0.1312651880644301]},
#              82: {'stocks': ['COP',
#                'ALXN',
#                'ROP',
#                'WFC',
#                'HD',
#                'AMP',
#                'PRU',
#                'CMI'],
#               'positions': [0.16058804073603583,
#                0.10450076544458094,
#                0.12768452484100834,
#                0.11388127170108987,
#                0.09504944999669056,
#                0.0862800676252778,
#                0.1611746177068539,
#                0.15084126194846284]},
#              83: {'stocks': ['LLL', 'CMS', 'ZBH'],
#               'positions': [0.11451567088237742,
#                0.3601032268914409,
#                0.5253811022261817]},
#              84: {'stocks': ['KLAC',
#                'BBY',
#                'EXR',
#                'XOM',
#                'PLD',
#                'UTX',
#                'LEG',
#                'GM'],
#               'positions': [0.12247432977528101,
#                0.2692644195874348,
#                0.03090884373693827,
#                0.03585937098543162,
#                0.12283376582211615,
#                0.26028819996989616,
#                0.031143833087528133,
#                0.1272272370353738]},
#              85: {'stocks': ['HSIC',
#                'AMP',
#                'AWK',
#                'FOXA',
#                'TMO',
#                'APTV',
#                'LYB',
#                'FLIR'],
#               'positions': [0.10076234348170228,
#                0.19712108495363495,
#                0.04265624712399301,
#                0.21402535161978764,
#                0.23326136659521374,
#                0.007038817604657694,
#                0.1986905768351147,
#                0.006444211785895978]},
#              86: {'stocks': ['FCX', 'RMD', 'ED', 'HUM', 'CMI'],
#               'positions': [0.12218902592708965,
#                0.3338144154991643,
#                0.14491943548792688,
#                0.02852053894305551,
#                0.3705565841427637]},
#              87: {'stocks': ['WM', 'TAP', 'AFL', 'GM'],
#               'positions': [0.7006479650325641,
#                0.03354331337643164,
#                0.2207499914524541,
#                0.0450587301385502]},
#              88: {'stocks': ['WU',
#                'DG',
#                'BF.B',
#                'GT',
#                'PHM',
#                'TSS',
#                'BDX',
#                'FLIR'],
#               'positions': [0.15012699184676231,
#                0.02147853865168942,
#                0.11095721653995518,
#                0.20210466774205607,
#                0.05797299041434497,
#                0.12235022999390247,
#                0.1840417144695816,
#                0.150967650341708]},
#              89: {'stocks': ['PSX',
#                'T',
#                'ORLY',
#                'MSFT',
#                'LKQ',
#                'CF',
#                'IBM',
#                'PEG'],
#               'positions': [0.022520907836086724,
#                0.12016863246060137,
#                0.1368977899741804,
#                0.20136767511463677,
#                0.1408557473087936,
#                0.018424604606157954,
#                0.16819286769273212,
#                0.19157177500681113]},
#              90: {'stocks': ['SIG',
#                'TSN',
#                'BLK',
#                'ABT',
#                'KR',
#                'GOOG',
#                'DIS',
#                'EW'],
#               'positions': [0.24309264956283289,
#                0.1351760285124244,
#                0.21639296882655,
#                0.06349761023072059,
#                0.04506602399030131,
#                0.05299638024520845,
#                0.07007369377027917,
#                0.17370464486168316]},
#              91: {'stocks': ['SBAC',
#                'C',
#                'AEE',
#                'HBI',
#                'LKQ',
#                'BF.B',
#                'RMD',
#                'TDG',
#                'DHI'],
#               'positions': [0.15804901789366213,
#                0.035583335954741085,
#                0.005558975498030624,
#                0.13616540456744738,
#                0.14995184855226873,
#                0.16002056889794708,
#                0.11799108573809278,
#                0.11281528503030026,
#                0.12386447786750988]},
#              92: {'stocks': ['TEL',
#                'FRT',
#                'MDLZ',
#                'ADSK',
#                'LNC',
#                'CHRW',
#                'BBY',
#                'ULTA',
#                'GM'],
#               'positions': [0.08740805893904856,
#                0.12669735145334932,
#                0.12003989583979321,
#                0.009141840350283334,
#                0.1538293791957278,
#                0.129107007041306,
#                0.16983223414957116,
#                0.20320334163627177,
#                0.0007408913946488373]},
#              93: {'stocks': ['AES',
#                'MS',
#                'LNC',
#                'VNO',
#                'DWDP',
#                'ABC',
#                'PHM',
#                'GWW'],
#               'positions': [0.20691416230413948,
#                0.004477936496562678,
#                0.15002874237954075,
#                0.26912986867355965,
#                0.09216085458790868,
#                0.02544232686314643,
#                0.24524520593448346,
#                0.006600902760658829]},
#              94: {'stocks': ['PKI', 'HOG', 'HES', 'CBOE', 'MON', 'BHGE'],
#               'positions': [0.15401021692908357,
#                0.21971058053827922,
#                0.007700254856531211,
#                0.1461338400524671,
#                0.16451981244700867,
#                0.3079252951766302]},
#              95: {'stocks': ['DPS', 'SBAC', 'PGR'],
#               'positions': [0.21633075941099192,
#                0.43438339989086294,
#                0.34928584069814506]},
#              96: {'stocks': ['BAC',
#                'PCAR',
#                'KMX',
#                'NLSN',
#                'DVN',
#                'HUM',
#                'FITB',
#                'LRCX'],
#               'positions': [0.1682458709151115,
#                0.18235601465232149,
#                0.028880704726970047,
#                0.17448882072017188,
#                0.008029520273792686,
#                0.1766733657375375,
#                0.13917618952832417,
#                0.12214951344577071]},
#              97: {'stocks': ['CAT', 'AGN', 'WMB', 'MNST'],
#               'positions': [0.4117248469694843,
#                0.1460884803931431,
#                0.4038875145455597,
#                0.038299158091812786]},
#              98: {'stocks': ['KSS',
#                'VZ',
#                'ALXN',
#                'UPS',
#                'TPR',
#                'AMGN',
#                'SWK',
#                'XRX',
#                'BF.B'],
#               'positions': [0.041952721715209654,
#                0.06991019433683647,
#                0.2150816133105262,
#                0.13336057206715415,
#                0.07036048792690082,
#                0.0561932194467474,
#                0.22687477618255888,
#                0.10396537325596601,
#                0.0823010417581003]},
#              99: {'stocks': ['PHM', 'DVN', 'SJM', 'HBI', 'PM'],
#               'positions': [0.10360775900034988,
#                0.31345509791218706,
#                0.006099881246126899,
#                0.2912625915738707,
#                0.2855746702674654]},
#              100: {'stocks': ['AMZN',
#                'MNST',
#                'ATVI',
#                'K',
#                'WMT',
#                'MYL',
#                'SRE'],
#               'positions': [0.1598794264422791,
#                0.1636913334584551,
#                0.10051781288976787,
#                0.07957011325713681,
#                0.22866425015289954,
#                0.035612827826315724,
#                0.23206423597314588]},
#              101: {'stocks': ['MU', 'CSCO', 'GPS'],
#               'positions': [0.1758190435466264,
#                0.4370067953896792,
#                0.38717416106369446]},
#              102: {'stocks': ['RHI', 'LNC', 'MPC', 'SEE', 'TXN', 'MTD'],
#               'positions': [0.2572789175404611,
#                0.08492960889407378,
#                0.2905524339735131,
#                0.08961652371185333,
#                0.21291821184619145,
#                0.064704304033907]},
#              103: {'stocks': ['QRVO',
#                'NBL',
#                'DUK',
#                'PX',
#                'EW',
#                'WDC',
#                'LH',
#                'MLM'],
#               'positions': [0.08545593311722724,
#                0.03562873212295558,
#                0.08081533003721467,
#                0.13590132778021055,
#                0.17158313730372463,
#                0.12312948843007403,
#                0.18885148026253776,
#                0.17863457094605556]},
#              104: {'stocks': ['EQIX',
#                'RF',
#                'APC',
#                'GOOGL',
#                'FAST',
#                'AEE',
#                'AMG',
#                'SRE',
#                'KMX'],
#               'positions': [0.22809408319027932,
#                0.22844402641734424,
#                0.0957902854602585,
#                0.07120722890004921,
#                0.005729269595446823,
#                0.1904841120422451,
#                0.03747174847647603,
#                0.05799961212431485,
#                0.084779633793586]},
#              105: {'stocks': ['SBAC',
#                'KIM',
#                'COTY',
#                'ORLY',
#                'XL',
#                'WBA',
#                'BA',
#                'HCP',
#                'CFG'],
#               'positions': [0.2389478279039708,
#                0.02856808077567132,
#                0.05134987405049969,
#                0.0807030183414798,
#                0.17634324044249183,
#                0.018967856574302135,
#                0.1589823230919993,
#                0.15598227553606117,
#                0.09015550328352392]},
#              106: {'stocks': ['PCG',
#                'FLS',
#                'BAC',
#                'FBHS',
#                'TAP',
#                'ICE',
#                'BWA',
#                'PDCO',
#                'CNC'],
#               'positions': [0.25248792419721694,
#                0.02919551103196162,
#                0.02068467552143558,
#                0.17360896942664114,
#                0.1847337855371858,
#                0.00772974804555309,
#                0.1065685454108438,
#                0.08147998202084386,
#                0.14351085880831835]},
#              107: {'stocks': ['CL',
#                'GIS',
#                'AAP',
#                'ED',
#                'CCL',
#                'DISCA',
#                'EOG',
#                'MSI',
#                'SYY'],
#               'positions': [0.09724793670774494,
#                0.0827845559585926,
#                0.14945466507496305,
#                0.10282374480570093,
#                0.16906592135813536,
#                0.16138760696632895,
#                0.05284704409937814,
#                0.06808806018409916,
#                0.116300464845057]},
#              108: {'stocks': ['AES', 'EXPE', 'AIV', 'LUK'],
#               'positions': [0.4189967202468559,
#                0.06553811738023455,
#                0.2901231272951425,
#                0.22534203507776707]},
#              109: {'stocks': ['ARE', 'TSN', 'MAS', 'AAPL', 'NSC'],
#               'positions': [0.29914742998367577,
#                0.11722302812537568,
#                0.17418419202244353,
#                0.19629248050791243,
#                0.21315286936059247]},
#              110: {'stocks': ['AMZN', 'AWK', 'DISCK', 'REG'],
#               'positions': [0.24889706693000238,
#                0.3407508760780783,
#                0.34939207207922807,
#                0.06095998491269126]},
#              111: {'stocks': ['BHF', 'CNP', 'WEC', 'HAS', 'GOOG', 'SLB'],
#               'positions': [0.21102369208924648,
#                0.2604475597582531,
#                0.05555346442887173,
#                0.07443792345822338,
#                0.2655958278602943,
#                0.132941532405111]},
#              112: {'stocks': ['ARE',
#                'KMB',
#                'NTRS',
#                'UPS',
#                'ALB',
#                'M',
#                'AVGO',
#                'AYI',
#                'IQV'],
#               'positions': [0.13237443204311652,
#                0.017740565380450535,
#                0.051195148438720625,
#                0.04160546508496919,
#                0.16155742698241296,
#                0.19425514183696166,
#                0.007127980760586696,
#                0.17858356454769664,
#                0.21556027492508514]},
#              113: {'stocks': ['RSG', 'AET', 'ALL', 'DLTR'],
#               'positions': [0.21250653795123828,
#                0.2694020398789409,
#                0.06354240279557202,
#                0.45454901937424885]},
#              114: {'stocks': ['LH',
#                'EW',
#                'VLO',
#                'CDNS',
#                'TDG',
#                'WMT',
#                'CMS',
#                'PG',
#                'MON'],
#               'positions': [0.2800092559917068,
#                0.015561513064620391,
#                0.05857382416394241,
#                0.22573220395812302,
#                0.1288207299988189,
#                0.0007505872346891576,
#                0.21412176137938546,
#                0.005101092351189795,
#                0.07132903185752407]},
#              115: {'stocks': ['JNPR', 'EMN', 'PKG', 'MAR'],
#               'positions': [0.037722820803593606,
#                0.37093465596770414,
#                0.13201552805479186,
#                0.4593269951739104]},
#              116: {'stocks': ['COG', 'FBHS', 'CSRA'],
#               'positions': [0.6397682651653124,
#                0.35738157391713565,
#                0.002850160917551772]},
#              117: {'stocks': ['AMG', 'EQT', 'ED', 'FB'],
#               'positions': [0.24028401481802095,
#                0.3658886612287083,
#                0.05104161777925941,
#                0.34278570617401133]},
#              118: {'stocks': ['VMC', 'INCY', 'CCL', 'HAL', 'SIG'],
#               'positions': [0.3118733436190231,
#                0.015858725748570415,
#                0.009173994520786656,
#                0.4530738973501446,
#                0.21002003876147513]},
#              119: {'stocks': ['PNC', 'STZ', 'LEN', 'CTL'],
#               'positions': [0.27626590079054586,
#                0.20819009427293603,
#                0.31593335437818443,
#                0.19961065055833369]},
#              120: {'stocks': ['GPC', 'ES', 'ULTA', 'ROP', 'NDAQ', 'FE', 'LLY'],
#               'positions': [0.09430515448731898,
#                0.07194252080523235,
#                0.20827598301885292,
#                0.24270710190097133,
#                0.0023459683582681685,
#                0.21778665331249042,
#                0.16263661811686575]},
#              121: {'stocks': ['HP',
#                'VAR',
#                'PGR',
#                'FMC',
#                'SRCL',
#                'CTL',
#                'SLB',
#                'LNC'],
#               'positions': [0.021382039356619222,
#                0.07668242236929351,
#                0.14101300943436096,
#                0.23646271066793992,
#                0.12379706919642096,
#                0.06597690573317488,
#                0.06405293714944041,
#                0.2706329060927502]},
#              122: {'stocks': ['CBOE', 'FIS', 'NOV'],
#               'positions': [0.37361205539291037,
#                0.3283187339094665,
#                0.29806921069762304]},
#              123: {'stocks': ['BLK', 'LNC', 'BRK.B', 'FRT'],
#               'positions': [0.37672826393849784,
#                0.055695175513008746,
#                0.4059726347414469,
#                0.1616039258070466]},
#              124: {'stocks': ['JNPR',
#                'PPL',
#                'BEN',
#                'TAP',
#                'ORCL',
#                'MSFT',
#                'CCI'],
#               'positions': [0.09629561651739883,
#                0.20218709739292087,
#                0.22932577164876786,
#                0.09682929496794145,
#                0.12720793588478174,
#                0.13397657892616788,
#                0.11417770466202148]},
#              125: {'stocks': ['CMS',
#                'AJG',
#                'DWDP',
#                'DUK',
#                'K',
#                'CCI',
#                'HST',
#                'ALK'],
#               'positions': [0.053360674227856765,
#                0.06331594599400145,
#                0.1645940537937217,
#                0.19181761100939826,
#                0.08893399556170518,
#                0.16028304024248094,
#                0.09097288555001974,
#                0.18672179362081584]},
#              126: {'stocks': ['EIX', 'RHT', 'COF', 'BAX', 'AXP', 'MLM', 'PH'],
#               'positions': [0.1382991952680606,
#                0.2630029387604478,
#                0.19109136291849405,
#                0.005918822167546309,
#                0.2613735626262704,
#                0.0012980232605069766,
#                0.13901609499867384]},
#              127: {'stocks': ['MRO',
#                'UNH',
#                'INFO',
#                'NOV',
#                'DISCK',
#                'HUM',
#                'AYI',
#                'EL'],
#               'positions': [0.04639891552595209,
#                0.03124470189007028,
#                0.16720340367505368,
#                0.20001362008624987,
#                0.07688655650652455,
#                0.23841871633357756,
#                0.10818793181160369,
#                0.1316461541709682]},
#              128: {'stocks': ['TRV',
#                'PX',
#                'APC',
#                'AEE',
#                'FITB',
#                'JPM',
#                'IQV',
#                'EQR',
#                'ITW'],
#               'positions': [0.07059347886041828,
#                0.07010810116020516,
#                0.10464512275510851,
#                0.09404481922481958,
#                0.17348655745630992,
#                0.13414282062146204,
#                0.07826486890022484,
#                0.16604641682081098,
#                0.10866781420064055]},
#              129: {'stocks': ['GILD',
#                'AVB',
#                'GOOG',
#                'KIM',
#                'PEP',
#                'SNI',
#                'AMGN',
#                'MAA'],
#               'positions': [0.06529726626615105,
#                0.04040576927670992,
#                0.13753031068091684,
#                0.08412319684239492,
#                0.22255007371941127,
#                0.24155230164224825,
#                0.1648126133508694,
#                0.04372846822129835]},
#              130: {'stocks': ['BLL',
#                'VRSK',
#                'WYN',
#                'GPS',
#                'SNI',
#                'AME',
#                'AGN',
#                'RRC'],
#               'positions': [0.3518204308023511,
#                0.008276313536951917,
#                0.20933302378966867,
#                0.05695496740790917,
#                0.2540166497518801,
#                0.02167017851937321,
#                0.02653423726307066,
#                0.07139419892879516]},
#              131: {'stocks': ['APD', 'VAR', 'PCLN', 'LNT'],
#               'positions': [0.3600632333954601,
#                0.07197675790175413,
#                0.10495880616552522,
#                0.4630012025372607]},
#              132: {'stocks': ['HCP', 'ESS', 'BBT', 'PPG', 'NCLH', 'CELG'],
#               'positions': [0.35182121761836277,
#                0.2535131736176906,
#                0.129731881046304,
#                0.09693256174760326,
#                0.06527462948775845,
#                0.1027265364822807]},
#              133: {'stocks': ['DPS', 'PKI', 'TRV', 'TSCO'],
#               'positions': [0.3597678334088289,
#                0.22428474314723312,
#                0.1846768973222394,
#                0.2312705261216986]},
#              134: {'stocks': ['HCP', 'NVDA', 'TJX', 'PLD', 'PGR', 'OMC'],
#               'positions': [0.17273142626436527,
#                0.2322763733486796,
#                0.2328075571733136,
#                0.05788666663210363,
#                0.2416822776353721,
#                0.06261569894616587]},
#              135: {'stocks': ['LRCX',
#                'ISRG',
#                'NKE',
#                'ECL',
#                'BLL',
#                'TWX',
#                'KMX',
#                'AMP',
#                'ANSS'],
#               'positions': [0.14106421522014567,
#                0.1709337331555165,
#                0.18834211378863158,
#                0.19265939032727258,
#                0.03489472828559545,
#                0.0181593472135794,
#                0.04977609215137226,
#                0.05252883750060809,
#                0.15164154235727847]},
#              136: {'stocks': ['PAYX',
#                'ALL',
#                'ZION',
#                'AET',
#                'GLW',
#                'LH',
#                'XEL',
#                'ED'],
#               'positions': [0.267406592049247,
#                0.21778771632721153,
#                0.10349762179820736,
#                0.07056943509030536,
#                0.026329536631708967,
#                0.08583851883901934,
#                0.05410001015286602,
#                0.17447056911143446]},
#              137: {'stocks': ['FLR', 'FFIV', 'STI', 'MPC', 'CERN', 'BLK'],
#               'positions': [0.05638625345553699,
#                0.23006467598197167,
#                0.09473972278770819,
#                0.2513755949318936,
#                0.2794147987527157,
#                0.08801895409017396]},
#              138: {'stocks': ['HLT',
#                'CAT',
#                'SPG',
#                'VTR',
#                'FLR',
#                'EXPD',
#                'DHR'],
#               'positions': [0.03471535620861389,
#                0.26853986546237485,
#                0.11788733109868413,
#                0.10267814192274342,
#                0.026628945850851335,
#                0.25055143215289216,
#                0.19899892730384014]},
#              139: {'stocks': ['AWK', 'HOLX', 'RE'],
#               'positions': [0.35737611967606314,
#                0.47550269711018245,
#                0.16712118321375438]},
#              140: {'stocks': ['BBY', 'AFL', 'PM', 'SYMC', 'AVB', 'EIX'],
#               'positions': [0.08732840689688426,
#                0.1937512345979533,
#                0.27570358743981516,
#                0.08720887588217394,
#                0.2141500500387292,
#                0.1418578451444442]},
#              141: {'stocks': ['KSS',
#                'GOOG',
#                'LEN',
#                'KHC',
# ...
#              952: {'stocks': ['ABC',
#                'NBL',
#                'JNPR',
#                'NCLH',
#                'HRL',
#                'SJM',
#                'INFO',
#                'MHK'],
#               'positions': [0.04344330323744526,
#                0.14810364498765383,
#                0.1365368026388813,
#                0.05376033830288055,
#                0.2534415622438528,
#                0.18782811945024286,
#                0.17347759404332205,
#                0.0034086350957214925]},
#              953: {'stocks': ['PDCO',
#                'CBOE',
#                'DHI',
#                'AWK',
#                'ALL',
#                'TXT',
#                'WU',
#                'C',
#                'UTX'],
#               'positions': [0.1821395998846498,
#                0.040352668641508715,
#                0.17268468015761135,
#                0.15888639117155448,
#                0.06630878757447128,
#                0.14082839461908328,
#                0.10265402187544882,
#                0.029315931882467224,
#                0.1068295241932051]},
#              954: {'stocks': ['INFO', 'DWDP', 'DAL', 'RSG'],
#               'positions': [0.40489052430820405,
#                0.21146304578561675,
#                0.07234205676722646,
#                0.31130437313895265]},
#              955: {'stocks': ['DE', 'TSCO', 'NUE', 'KLAC', 'PH'],
#               'positions': [0.08687696413637735,
#                0.1480746403042622,
#                0.1675011516486999,
#                0.03792735829418776,
#                0.5596198856164729]},
#              956: {'stocks': ['WU',
#                'UHS',
#                'HRL',
#                'CTXS',
#                'APD',
#                'INCY',
#                'TIF'],
#               'positions': [0.18412571711413814,
#                0.2273536654215902,
#                0.07703111924851011,
#                0.0895602785726345,
#                0.06954740592514955,
#                0.11054646214162002,
#                0.24183535157635752]},
#              957: {'stocks': ['HIG',
#                'EA',
#                'NWSA',
#                'ANDV',
#                'AIZ',
#                'WYNN',
#                'VRSK',
#                'KSS',
#                'MRK'],
#               'positions': [0.12650046559275593,
#                0.10170859833077228,
#                0.06826591205266705,
#                0.16691628393436625,
#                0.010212871724584826,
#                0.20490139448745165,
#                0.118382560433329,
#                0.12385363034682687,
#                0.07925828309724628]},
#              958: {'stocks': ['LMT', 'DVN', 'XLNX', 'ETN', 'FIS'],
#               'positions': [0.29533405278561087,
#                0.09622561586904457,
#                0.18744232512517267,
#                0.17231538908752447,
#                0.24868261713264753]},
#              959: {'stocks': ['MON', 'MO', 'HUM', 'KR', 'SEE', 'EIX'],
#               'positions': [0.2973836983344149,
#                0.13071377437031598,
#                0.05744798309009473,
#                0.36185554654668967,
#                0.08039268355837982,
#                0.07220631410010486]},
#              960: {'stocks': ['AON',
#                'DPS',
#                'ACN',
#                'HBI',
#                'CMA',
#                'CAH',
#                'EXPE',
#                'AAL'],
#               'positions': [0.17292046742848605,
#                0.028655962749301322,
#                0.16591962871587487,
#                0.32453044487593374,
#                0.06042716937451867,
#                0.014633608482894161,
#                0.12561715543629567,
#                0.10729556293669562]},
#              961: {'stocks': ['RMD', 'CSCO', 'SNPS', 'CBOE'],
#               'positions': [0.06268465367305409,
#                0.37159635666196145,
#                0.08969326669275678,
#                0.4760257229722277]},
#              962: {'stocks': ['LRCX', 'MCD', 'NI'],
#               'positions': [0.11183874554399724,
#                0.3150392626480233,
#                0.5731219918079795]},
#              963: {'stocks': ['WYN', 'AES', 'BHF', 'MRK', 'RSG'],
#               'positions': [0.17076293001716356,
#                0.19481618105714857,
#                0.4220212653273427,
#                0.03486837281053305,
#                0.17753125078781204]},
#              964: {'stocks': ['ETN', 'AAL', 'HPE'],
#               'positions': [0.1756721764535565,
#                0.3758119929116456,
#                0.4485158306347979]},
#              965: {'stocks': ['PEP', 'MON', 'CCI'],
#               'positions': [0.04578088769526313,
#                0.3517980107755348,
#                0.6024211015292021]},
#              966: {'stocks': ['NEE', 'HBAN', 'ESS', 'ILMN'],
#               'positions': [0.07298475338474694,
#                0.13875792543970425,
#                0.4040257496173161,
#                0.38423157155823284]},
#              967: {'stocks': ['UDR',
#                'IPG',
#                'KR',
#                'M',
#                'CFG',
#                'RF',
#                'ABBV',
#                'MU',
#                'EXPD'],
#               'positions': [0.03210163292348941,
#                0.07297607224761721,
#                0.2157194623696473,
#                0.10513278347995667,
#                0.009507752624174935,
#                0.08987393821209907,
#                0.13775174186949624,
#                0.19405500010283933,
#                0.1428816161706798]},
#              968: {'stocks': ['ADSK', 'GRMN', 'FLIR', 'ABBV'],
#               'positions': [0.19257135941285045,
#                0.3872797176340571,
#                0.3900792929821357,
#                0.030069629970956732]},
#              969: {'stocks': ['KHC', 'SYMC', 'CAH', 'COO', 'COTY', 'UAA'],
#               'positions': [0.26972044704795,
#                0.2635750998278774,
#                0.18834536780915528,
#                0.13145582222653127,
#                0.11939739059107268,
#                0.027505872497413486]},
#              970: {'stocks': ['STT', 'CHD', 'KSU', 'JPM'],
#               'positions': [0.46490762152747506,
#                0.2727195991080434,
#                0.1534934840560321,
#                0.10887929530844948]},
#              971: {'stocks': ['CBS', 'UDR', 'PPG', 'ED', 'BHGE', 'AMP'],
#               'positions': [0.2167387954608815,
#                0.09253310006606155,
#                0.142066709624474,
#                0.20989025709854786,
#                0.17391088599829674,
#                0.16486025175173843]},
#              972: {'stocks': ['HBI',
#                'FDX',
#                'DRI',
#                'BMY',
#                'GRMN',
#                'BXP',
#                'ORLY',
#                'MMC',
#                'JPM'],
#               'positions': [0.05153251338005753,
#                0.15452681199815282,
#                0.0664159339246155,
#                0.15495833928227812,
#                0.13937097819645436,
#                0.06662290728698436,
#                0.15344761524501496,
#                0.07074076586185224,
#                0.14238413482459017]},
#              973: {'stocks': ['CVX',
#                'STZ',
#                'IPG',
#                'DOV',
#                'LB',
#                'CCL',
#                'FRT',
#                'MDLZ'],
#               'positions': [0.027688018848910104,
#                0.05856239769459408,
#                0.10211056010639487,
#                0.17625726316302778,
#                0.1818625608351644,
#                0.15427003290384392,
#                0.12649224269064235,
#                0.17275692375742252]},
#              974: {'stocks': ['CVX', 'CHK', 'AON'],
#               'positions': [0.33330569675892013,
#                0.2726925664812561,
#                0.39400173675982375]},
#              975: {'stocks': ['BSX', 'SYF', 'ABC', 'DRI', 'COG', 'CXO'],
#               'positions': [0.3223409240222392,
#                0.06765504728321194,
#                0.320538224779566,
#                0.05519840487152114,
#                0.047452540629974636,
#                0.18681485841348705]},
#              976: {'stocks': ['SNPS', 'AMD', 'HRS'],
#               'positions': [0.7105360696746773,
#                0.0341621454065397,
#                0.2553017849187829]},
#              977: {'stocks': ['BWA', 'KIM', 'KSU'],
#               'positions': [0.4698186230058547,
#                0.23457972753325387,
#                0.2956016494608915]},
#              978: {'stocks': ['USB',
#                'FITB',
#                'JEC',
#                'CSCO',
#                'SNPS',
#                'MA',
#                'TDG',
#                'TXN',
#                'ES'],
#               'positions': [0.19082588324882627,
#                0.029049192343325793,
#                0.05617416105767069,
#                0.11603708253559408,
#                0.0027192566472413935,
#                0.006432348980153387,
#                0.16385646079692937,
#                0.24803887103440023,
#                0.18686674335585873]},
#              979: {'stocks': ['ANTM', 'COST', 'AEE', 'CMA', 'ULTA'],
#               'positions': [0.5285017626347598,
#                0.15752105761648272,
#                0.03898093185156533,
#                0.2493152085358104,
#                0.02568103936138182]},
#              980: {'stocks': ['TPR', 'GWW', 'MAR', 'RHT', 'OXY'],
#               'positions': [0.258094640719025,
#                0.3853175067281368,
#                0.18226949448626947,
#                0.16010155133002557,
#                0.0142168067365431]},
#              981: {'stocks': ['NCLH', 'HRB', 'STI'],
#               'positions': [0.33550877245553845,
#                0.5032367147151543,
#                0.16125451282930725]},
#              982: {'stocks': ['RE', 'KO', 'CSX', 'MCHP', 'GGP'],
#               'positions': [0.15429182738138467,
#                0.06825889044914911,
#                0.535961943389771,
#                0.20567775821203468,
#                0.03580958056766061]},
#              983: {'stocks': ['PGR',
#                'CXO',
#                'TMO',
#                'IRM',
#                'RCL',
#                'BF.B',
#                'TAP'],
#               'positions': [0.15616820332405354,
#                0.005712251435240316,
#                0.27940406386981825,
#                0.10841576895446851,
#                0.11659700034880058,
#                0.2775987629483402,
#                0.056103949119278705]},
#              984: {'stocks': ['PEP',
#                'USB',
#                'PH',
#                'HES',
#                'CCL',
#                'PGR',
#                'DHI',
#                'UPS',
#                'UHS'],
#               'positions': [0.03598933136743911,
#                0.03306552603136445,
#                0.1514054685964157,
#                0.17106957725485003,
#                0.14421368419875025,
#                0.16189894051724368,
#                0.008229997143914614,
#                0.1517261055540712,
#                0.14240136933595104]},
#              985: {'stocks': ['PFE', 'FL', 'EXC', 'MYL', 'RCL', 'CFG'],
#               'positions': [0.2247820504255231,
#                0.06762017408061019,
#                0.2830433705819916,
#                0.1720791187130444,
#                0.005472964813614428,
#                0.24700232138521627]},
#              986: {'stocks': ['JBHT', 'COO', 'ZION'],
#               'positions': [0.4305692340611334,
#                0.5409033182131561,
#                0.028527447725710548]},
#              987: {'stocks': ['VIAB',
#                'PBCT',
#                'AMGN',
#                'PFG',
#                'DLR',
#                'DVA',
#                'IFF',
#                'LNT',
#                'ES'],
#               'positions': [0.11738177157682204,
#                0.15469074917922138,
#                0.03656266298042098,
#                0.14454694489952183,
#                0.012446669477662707,
#                0.11763718471764188,
#                0.2019193132901931,
#                0.16743443257324137,
#                0.04738027130527482]},
#              988: {'stocks': ['DLR',
#                'CAG',
#                'VMC',
#                'BWA',
#                'DOV',
#                'BEN',
#                'REGN',
#                'RHT',
#                'CI'],
#               'positions': [0.04561797244350862,
#                0.043653573774590386,
#                0.1802797386031021,
#                0.03925177457197019,
#                0.18551054373539919,
#                0.19960832091293143,
#                0.2579403235239475,
#                0.01611178350859267,
#                0.03202596892595785]},
#              989: {'stocks': ['WEC',
#                'AME',
#                'CERN',
#                'ROST',
#                'TMO',
#                'EBAY',
#                'HD',
#                'MTD'],
#               'positions': [0.14229423076443215,
#                0.22356962891834567,
#                0.1855111024002863,
#                0.0044295731417131135,
#                0.2674176815267578,
#                0.049307519662911234,
#                0.03515307834679396,
#                0.09231718523875983]},
#              990: {'stocks': ['BBY', 'CFG', 'FLIR', 'MAR'],
#               'positions': [0.18680428364030247,
#                0.23041808766452088,
#                0.2713034927988563,
#                0.3114741358963204]},
#              991: {'stocks': ['CHD',
#                'EMN',
#                'PCG',
#                'TAP',
#                'PXD',
#                'VMC',
#                'LRCX',
#                'AMP',
#                'RCL'],
#               'positions': [0.06332232131099871,
#                0.20787357130993764,
#                0.0057000678775639855,
#                0.20318718674523686,
#                0.19397875047277297,
#                0.016499081379743655,
#                0.043815956634616245,
#                0.04081463272397705,
#                0.22480843154515273]},
#              992: {'stocks': ['ADS', 'DHI', 'KMB', 'ETR', 'LH', 'GRMN', 'LUV'],
#               'positions': [0.08316811504350635,
#                0.20572007620971633,
#                0.05484331643664741,
#                0.13338184597040997,
#                0.15388791328995,
#                0.19001507304134357,
#                0.1789836600084264]},
#              993: {'stocks': ['KR',
#                'CLX',
#                'ORLY',
#                'ANDV',
#                'TPR',
#                'WMT',
#                'ULTA'],
#               'positions': [0.11368219289675299,
#                0.19540052433998117,
#                0.022422691089085286,
#                0.13179220723586846,
#                0.16106644268164952,
#                0.16738020802868256,
#                0.20825573372797995]},
#              994: {'stocks': ['MGM',
#                'COL',
#                'UNP',
#                'TSS',
#                'DLTR',
#                'HBI',
#                'ZBH'],
#               'positions': [0.1881781940949048,
#                0.07332250735980536,
#                0.007418277834586817,
#                0.1370071337794542,
#                0.29136851262733243,
#                0.22518021942054456,
#                0.07752515488337187]},
#              995: {'stocks': ['NOC', 'KR', 'NLSN', 'GLW', 'HLT', 'WY', 'MCHP'],
#               'positions': [0.08148028678983328,
#                0.1240122538597692,
#                0.2646311539161487,
#                0.2173553922314522,
#                0.015360682064008119,
#                0.25820990212283823,
#                0.038950329015950275]},
#              996: {'stocks': ['JNPR', 'MTB', 'VRTX'],
#               'positions': [0.0586349332442359,
#                0.5018697409113217,
#                0.4394953258444424]},
#              997: {'stocks': ['IR', 'AOS', 'PAYX', 'HII'],
#               'positions': [0.3905926423549412,
#                0.043758746523193094,
#                0.3350507903081116,
#                0.23059782081375418]},
#              998: {'stocks': ['IP', 'PCAR', 'LNC'],
#               'positions': [0.32919824498902295,
#                0.19112815000348124,
#                0.47967360500749584]},
#              999: {'stocks': ['VIAB', 'GM', 'WU', 'EQR'],
#               'positions': [0.365959967926896,
#                0.09986150779662051,
#                0.43349293266862177,
#                0.10068559160786188]}})
